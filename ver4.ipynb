# %% [markdown]
# DBSCAN 사용 <br/>
# GridSearch를 사용한 파라미터 최적화 <br/>
# 빈도수를 이용한 불용어 250개를 추출하여 사용 <br/>
# 문서의 최빈 어휘 100개를 추출하여 벡터화한 것을 클러스터링 <br/>
# ver1과 비교하여 클러스터의 갯수와 노이즈 포인트의 갯수 모두 증가, 실루엣 스코어 미세하게 하락 <br/><br/>
#
# Best DBSCAN params: eps=0.1, min_samples=2 with Silhouette Score=-0.19123197729214664<br/>
# Number of clusters: 32<br/>
# Number of noise points: 1242

# %%
import os
import glob
import string
from tqdm import tqdm
from collections import Counter
from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# nltk 데이터 다운로드 (최초 실행 시 필요)
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# NLTK 초기화
lemmatizer = WordNetLemmatizer()

# %%
# txt 파일 경로 설정 (Google Drive의 경로로 변경)
path = '/content/drive/MyDrive/bitcoin_nlp'
output_path = '/content/drive/MyDrive/bitcoin_nlp/preprocessed'

# %%
# 불용어 리스트 생성 (빈도 기반)
def create_stopwords(documents, top_n=250):
    all_words = []
    for doc in documents:
        all_words.extend(doc[1].split())
    word_counts = Counter(all_words)
    stopwords = [word for word, count in word_counts.most_common(top_n)]
    return stopwords

# %%
# 구두점 제거 함수
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
# 불용어 제거 함수
def remove_stopwords(text, stopwords):
    words = text.split()
    words = [word for word in words if word not in stopwords]
    return ' '.join(words)

# %%
# 표제어 추출 함수
def lemmatize_words(text):
    words = text.split()
    lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]
    return ' '.join(lemmatized_words)

# %%
# 각 문서에서 빈도가 가장 높은 단어 100개 추출
def get_top_n_words(documents, n=100):
    top_words = []
    for filename, content in documents:
        words = content.split()
        word_counts = Counter(words)
        top_n = [word for word, count in word_counts.most_common(n)]
        top_words.append((filename, top_n))
    return top_words

# %%
# 최빈 단어 기반 문서 벡터 생성
def create_document_vectors(top_words, all_words_set):
    vectors = []
    for filename, words in top_words:
        vector = np.zeros(len(all_words_set))
        for word in words:
            if word in all_words_set:
                vector[list(all_words_set).index(word)] = 1
        vectors.append((filename, vector))
    return vectors

# %%
# 텍스트 파일 읽기 및 전처리 (구두점 제거, 불용어 제거, 표제어 추출)
def read_and_preprocess_files(path, stopwords):
    files = glob.glob(os.path.join(path, '*.txt'))
    documents = []
    for file in tqdm(files, desc="Reading and preprocessing files"):
        with open(file, 'r', encoding='utf-8') as f:
            content = f.read()
            content = remove_punctuation(content)  # 구두점 제거
            content = remove_stopwords(content, stopwords)  # 불용어 제거
            content = lemmatize_words(content)  # 표제어 추출
            documents.append((os.path.basename(file), content))
    return documents

# %%
# 전처리된 파일 저장
def save_preprocessed_files(documents, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    for filename, content in documents:
        # 기존 파일 이름 뒤에 '_preprocessed' 추가
        preprocessed_filename = os.path.splitext(filename)[0] + '_preprocessed.txt'
        with open(os.path.join(output_path, preprocessed_filename), 'w', encoding='utf-8') as f:
            f.write(content)

# %%
# 문서 읽기
documents = read_and_preprocess_files(path, [])
# Out:
# Reading and preprocessing files: 100%|██████████| 1373/1373 [00:43<00:00, 31.46it/s]

# %%
# 불용어 리스트 생성
stopwords = create_stopwords(documents)
stopwords
# Out:
# ['the',
#  'be',
#  'of',
#  'and',
#  'to',
#  'a',
#  'in',
#  'for',
#  '\u200b',
#  'that',
#  'will',
#  'The',
#  'on',
#  'as',
#  'or',
#  'with',
#  'by',
#  'have',
#  'can',
#  'use',
#  'an',
#  'from',
#  'this',
#  'not',
#  '\u200b\u200b',
#  'it',
#  'their',
#  'any',
#  'blockchain',
#  'which',
#  'data',
#  'network',
#  'at',
#  'all',
#  'market',
#  'other',
#  'This',
#  'service',
#  'contract',
#  'tokens',
#  '•',
#  'In',
#  'provide',
#  'users',
#  'we',
#  'platform',
#  '1',
#  'more',
#  'token',
#  'such',
#  'its',
#  'time',
#  'block',
#  'make',
#  'system',
#  'transaction',
#  'A',
#  'also',
#  'value',
#  'new',
#  'do',
#  'exchange',
#  '2',
#  'may',
#  'our',
#  'they',
#  'create',
#  'transactions',
#  'Token',
#  'include',
#  'information',
#  'only',
#  'one',
#  'process',
#  'need',
#  'allow',
#  'user',
#  'into',
#  'smart',
#  'base',
#  'each',
#  'through',
#  'trade',
#  'project',
#  'but',
#  'fee',
#  'technology',
#  'We',
#  '3',
#  'you',
#  'reward',
#  'price',
#  'number',
#  'these',
#  'chain',
#  'no',
#  '●',
#  'development',
#  'It',
#  'nod',
#  'if',
#  'account',
#  'order',
#  'Ethereum',
#  'than',
#  'require',
#  'key',
#  'fund',
#  'assets',
#  'offer',
#  'work',
#  'there',
#  'amount',
#  'ecosystem',
#  'decentralize',
#  'digital',
#  'company',
#  'protocol',
#  'build',
#  'community',
#  'where',
#  '5',
#  'business',
#  'game',
#  'support',
#  'financial',
#  'between',
#  '4',
#  'set',
#  '10',
#  'receive',
#  'who',
#  'cryptocurrency',
#  'would',
#  'follow',
#  'access',
#  'coin',
#  'team',
#  'node',
#  'share',
#  'change',
#  'when',
#  'risk',
#  'increase',
#  'them',
#  'security',
#  'stake',
#  'first',
#  'public',
#  'cost',
#  'own',
#  'Blockchain',
#  'For',
#  'over',
#  'model',
#  'purchase',
#  'payment',
#  'As',
#  'most',
#  'vote',
#  'address',
#  'result',
#  'distribute',
#  'take',
#  'design',
#  'different',
#  'content',
#  'Bitcoin',
#  'so',
#  'issue',
#  'case',
#  'without',
#  'give',
#  'up',
#  'pay',
#  'asset',
#  'develop',
#  'consensus',
#  'future',
#  'experience',
#  'many',
#  'If',
#  'store',
#  'same',
#  'Platform',
#  'become',
#  'able',
#  'your',
#  'mine',
#  'function',
#  'Tokens',
#  'way',
#  'world',
#  'then',
#  'within',
#  'hold',
#  'Network',
#  'should',
#  'party',
#  'out',
#  'form',
#  'wallet',
#  'transfer',
#  'some',
#  'part',
#  'two',
#  'exist',
#  'must',
#  'ensure',
#  'well',
#  '–',
#  'like',
#  'currency',
#  'could',
#  'both',
#  '6',
#  'enable',
#  'available',
#  'To',
#  'applications',
#  'mean',
#  'get',
#  'crypto',
#  'limit',
#  'feature',
#  'right',
#  'industry',
#  'example',
#  'generate',
#  'control',
#  'send',
#  'state',
#  'investment',
#  'every',
#  'supply',
#  'private',
#  'about',
#  'power',
#  'hash',
#  'All',
#  'application',
#  'sell',
#  'Smart',
#  'liquidity',
#  'high',
#  'run',
#  'storage',
#  'total',
#  'current',
#  'while']

# %%
# 문서 읽기
documents = read_and_preprocess_files(path, stopwords)
# Out:
# Reading and preprocessing files: 100%|██████████| 1373/1373 [00:38<00:00, 35.29it/s]

# %%
# 전처리된 파일 저장
save_preprocessed_files(documents, output_path)

# %%
# 각 문서에서 빈도가 가장 높은 단어 100개 추출
top_words = get_top_n_words(documents)

# %%
# 모든 문서에서 등장하는 모든 단어의 집합 생성
all_words_set = set()
for filename, words in top_words:
    all_words_set.update(words)

# %%
# 최빈 단어 기반 문서 벡터 생성
document_vectors = create_document_vectors(top_words, all_words_set)

# %%
# 벡터를 numpy 배열로 변환 및 스케일링
filenames, vectors = zip(*document_vectors)
X = np.array(vectors)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Grid Search를 사용한 DBSCAN 파라미터 최적화
eps_values = np.arange(0.1, 2.1, 0.1)
min_samples_values = list(range(2, 31, 2))
best_dbscan_score = -1
best_dbscan_params = None

# %%
for eps in eps_values:
    for min_samples in min_samples_values:
        print(f"Running DBSCAN with eps={eps}, min_samples={min_samples}")
        dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean')
        clusters = dbscan.fit_predict(X_scaled)

        # 클러스터링 평가 (Silhouette Score 사용)
        if len(set(clusters)) > 1:
            score = silhouette_score(X_scaled, clusters)
            print(f"Silhouette Score: {score}")
            if score > best_dbscan_score:
                best_dbscan_score = score
                best_dbscan_params = (eps, min_samples)
# Out:
# Running DBSCAN with eps=0.1, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.1, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.1, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.1, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.1, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.2, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.2, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.2, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.2, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.30000000000000004, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.30000000000000004, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.30000000000000004, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.30000000000000004, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.4, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.4, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.4, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.4, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.5, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.5, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.5, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.5, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.6, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.6, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.6, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.6, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.7000000000000001, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.7000000000000001, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.7000000000000001, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.7000000000000001, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.8, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.8, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.8, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.8, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=0.9, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.9, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=0.9, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=0.9, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.0, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.0, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.0, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.0, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.1, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.1, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.1, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.1, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.2000000000000002, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.2000000000000002, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.2000000000000002, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.2000000000000002, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.3000000000000003, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.3000000000000003, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.3000000000000003, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.3000000000000003, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.4000000000000001, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.4000000000000001, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.4000000000000001, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.4000000000000001, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.5000000000000002, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.5000000000000002, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.5000000000000002, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.5000000000000002, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.6, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.6, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.6, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.6, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.7000000000000002, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.7000000000000002, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.7000000000000002, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.7000000000000002, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.8000000000000003, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.8000000000000003, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.8000000000000003, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.8000000000000003, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=1.9000000000000001, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.9000000000000001, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=1.9000000000000001, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=1.9000000000000001, min_samples=30
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=2
# Silhouette Score: -0.19123197729214664
# Running DBSCAN with eps=2.0, min_samples=4
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=2.0, min_samples=6
# Silhouette Score: -0.24913481488600214
# Running DBSCAN with eps=2.0, min_samples=8
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=10
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=12
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=14
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=16
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=18
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=20
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=22
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=24
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=26
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=28
# Silhouette Score: -0.2621043250725149
# Running DBSCAN with eps=2.0, min_samples=30
# Silhouette Score: -0.2621043250725149

# %%
# 최적의 파라미터로 DBSCAN 클러스터링 수행
if best_dbscan_params:
    eps, min_samples = best_dbscan_params
    print(f"Best DBSCAN params: eps={eps}, min_samples={min_samples} with Silhouette Score={best_dbscan_score}")
    dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean')
    clusters = dbscan.fit_predict(X_scaled)

    # 각 클러스터에 속한 파일들 출력 및 CSV 저장
    clustered_files = {}
    for file, cluster in zip(filenames, clusters):
        if cluster not in clustered_files:
            clustered_files[cluster] = []
        clustered_files[cluster].append(file)

    # 클러스터 결과 출력
    n_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
    n_noise = list(clusters).count(-1)
    print(f"Number of clusters: {n_clusters}")
    print(f"Number of noise points: {n_noise}")

    # 각 클러스터의 파일 리스트 출력
    for cluster, file_list in clustered_files.items():
        print(f"Cluster {cluster}:")
        for file in file_list:
            print(f"  {file}")

    # 결과를 CSV 파일로 저장
    results = {'File': filenames, 'Cluster': clusters}
    results_df = pd.DataFrame(results)
    results_df.to_csv('/content/drive/MyDrive/bitcoin_nlp/dbscan_results.csv', index=False)
    print("DBSCAN 결과가 CSV 파일로 저장되었습니다.")

else:
    print("No suitable parameters found for DBSCAN.")
# Out:
# Best DBSCAN params: eps=0.1, min_samples=2 with Silhouette Score=-0.19123197729214664
# Number of clusters: 32
# Number of noise points: 1242
# Cluster -1:
#   WaBi WABI whitepapers - whitepaper.io.txt
#   BLOCKv VEE whitepapers - whitepaper.io.txt
#   Electric Vehicle Zone EVZ whitepapers - whitepaper.io.txt
#   ScPrime SCP whitepapers - whitepaper.io.txt
#   FOAM FOAM whitepapers - whitepaper.io.txt
#   ShareToken SHR whitepapers - whitepaper.io.txt
#   PEAKDEFI PEAK whitepapers - whitepaper.io.txt
#   Mysterium MYST whitepapers - whitepaper.io.txt
#   Hegic HEGIC whitepapers - whitepaper.io.txt
#   Zano ZANO whitepapers - whitepaper.io.txt
#   Kylin KYL whitepapers - whitepaper.io.txt
#   POA POA whitepapers - whitepaper.io.txt
#   ProximaX XPX whitepapers - whitepaper.io.txt
#   Ignis IGNIS whitepapers - whitepaper.io.txt
#   N.Exchange NEX whitepapers - whitepaper.io.txt
#   BioPassport Token BIOT whitepapers - whitepaper.io.txt
#   Edgeless EDG whitepapers - whitepaper.io.txt
#   GamerCoin GHX whitepapers - whitepaper.io.txt
#   Tokenomy TEN whitepapers - whitepaper.io.txt
#   Ariva ARV whitepapers - whitepaper.io.txt
#   BaaSid BAAS whitepapers - whitepaper.io.txt
#   REVV REVV whitepapers - whitepaper.io.txt
#   MultiVAC MTV whitepapers - whitepaper.io.txt
#   RING X PLATFORM RINGX whitepapers - whitepaper.io.txt
#   Polaris Share POLA whitepapers - whitepaper.io.txt
#   Dfyn Network DFYN whitepapers - whitepaper.io.txt
#   BnkToTheFuture BFT whitepapers - whitepaper.io.txt
#   Newton NEW whitepapers - whitepaper.io.txt
#   ILCoin ILC whitepapers - whitepaper.io.txt
#   The Transfer Token TTT whitepapers - whitepaper.io.txt
#   Cirus Foundation CIRUS whitepapers - whitepaper.io.txt
#   STEM CELL COIN SCC whitepapers - whitepaper.io.txt
#   BHP Network BHP whitepapers - whitepaper.io.txt
#   Nexus NXS whitepapers - whitepaper.io.txt
#   Covesting COV whitepapers - whitepaper.io.txt
#   V Systems VSYS whitepapers - whitepaper.io.txt
#   1World 1WO whitepapers - whitepaper.io.txt
#   Bytecoin BCN whitepapers - whitepaper.io.txt
#   QLCchain QLC whitepapers - whitepaper.io.txt
#   Viacoin VIA whitepapers - whitepaper.io.txt
#   GridCoin GRC whitepapers - whitepaper.io.txt
#   Torum XTM whitepapers - whitepaper.io.txt
#   Populous PPT whitepapers - whitepaper.io.txt
#   Aidos Kuneen ADK whitepapers - whitepaper.io.txt
#   SALT SALT whitepapers - whitepaper.io.txt
#   InsurAce INSUR whitepapers - whitepaper.io.txt
#   QATAR 2022 TOKEN FWC whitepapers - whitepaper.io.txt
#   Sora XOR whitepapers - whitepaper.io.txt
#   Factom FCT whitepapers - whitepaper.io.txt
#   Monetha MTH whitepapers - whitepaper.io.txt
#   Atari Token ATRI whitepapers - whitepaper.io.txt
#   Bitcoin Private BTCP whitepapers - whitepaper.io.txt
#   BullPerks BLP whitepapers - whitepaper.io.txt
#   CryptoFranc XCHF whitepapers - whitepaper.io.txt
#   Nxt NXT whitepapers - whitepaper.io.txt
#   Enecuum ENQ whitepapers - whitepaper.io.txt
#   Minter Network BIP whitepapers - whitepaper.io.txt
#   Glitch GLCH whitepapers - whitepaper.io.txt
#   Linker Coin LNC whitepapers - whitepaper.io.txt
#   SunContract SNC whitepapers - whitepaper.io.txt
#   TenX PAY whitepapers - whitepaper.io.txt
#   MAPS MAPS whitepapers - whitepaper.io.txt
#   BABB BAX whitepapers - whitepaper.io.txt
#   Lympo LYM whitepapers - whitepaper.io.txt
#   TokenCard TKN whitepapers - whitepaper.io.txt
#   Aurora AOA whitepapers - whitepaper.io.txt
#   FortKnoxster FKX whitepapers - whitepaper.io.txt
#   Metaverse ETP ETP whitepapers - whitepaper.io.txt
#   Achain ACT whitepapers - whitepaper.io.txt
#   DeepBrain Chain DBC whitepapers - whitepaper.io.txt
#   ColossusXT COLX whitepapers - whitepaper.io.txt
#   Oxbull.tech OXB whitepapers - whitepaper.io.txt
#   Litecoin Cash LCC whitepapers - whitepaper.io.txt
#   GPEX GPX whitepapers - whitepaper.io.txt
#   XTRABYTES XBY whitepapers - whitepaper.io.txt
#   Perth Mint Gold Token PMGT whitepapers - whitepaper.io.txt
#   VestChain VEST whitepapers - whitepaper.io.txt
#   Einsteinium EMC2 whitepapers - whitepaper.io.txt
#   EvidenZ BCDT whitepapers - whitepaper.io.txt
#   Nebulas NAS whitepapers - whitepaper.io.txt
#   SmartMesh SMT whitepapers - whitepaper.io.txt
#   TOP Network TOP whitepapers - whitepaper.io.txt
#   Mobilian Coin MBN whitepapers - whitepaper.io.txt
#   DuckDaoDime DDIM whitepapers - whitepaper.io.txt
#   DSLA Protocol DSLA whitepapers - whitepaper.io.txt
#   SIBCoin SIB whitepapers - whitepaper.io.txt
#   Skycoin SKY whitepapers - whitepaper.io.txt
#   SafeMoon Inu SMI whitepapers - whitepaper.io.txt
#   Lamden TAU whitepapers - whitepaper.io.txt
#   Swingby SWINGBY whitepapers - whitepaper.io.txt
#   Convergence CONV whitepapers - whitepaper.io.txt
#   Graphlinq Protocol GLQ whitepapers - whitepaper.io.txt
#   SifChain erowan whitepapers - whitepaper.io.txt
#   Egretia EGT whitepapers - whitepaper.io.txt
#   Cryptaur CPT whitepapers - whitepaper.io.txt
#   PAID Network PAID whitepapers - whitepaper.io.txt
#   Genaro Network GNX whitepapers - whitepaper.io.txt
#   GNY GNY whitepapers - whitepaper.io.txt
#   Blocknet BLOCK whitepapers - whitepaper.io.txt
#   CyberMiles CMT whitepapers - whitepaper.io.txt
#   EXMO EXM whitepapers - whitepaper.io.txt
#   Safe Haven SHA whitepapers - whitepaper.io.txt
#   KubeCoin KUBE whitepapers - whitepaper.io.txt
#   Repo Coin REPO whitepapers - whitepaper.io.txt
#   SpaceChain SPC whitepapers - whitepaper.io.txt
#   Primecoin XPM whitepapers - whitepaper.io.txt
#   Kava Swap SWP whitepapers - whitepaper.io.txt
#   IQeon IQN whitepapers - whitepaper.io.txt
#   Wagerr WGR whitepapers - whitepaper.io.txt
#   Internet Node Token INT whitepapers - whitepaper.io.txt
#   CyberVein CVT whitepapers - whitepaper.io.txt
#   Attila ATT whitepapers - whitepaper.io.txt
#   Wicrypt WNT whitepapers - whitepaper.io.txt
#   KamPay KAMPAY whitepapers - whitepaper.io.txt
#   Stakeborg DAO STANDARD whitepapers - whitepaper.io.txt
#   WebDollar WEBD whitepapers - whitepaper.io.txt
#   Gleec GLEEC whitepapers - whitepaper.io.txt
#   Hydro Protocol HOT whitepapers - whitepaper.io.txt
#   Libra Credit LBA whitepapers - whitepaper.io.txt
#   Gulden NLG whitepapers - whitepaper.io.txt
#   ArdCoin ARDX whitepapers - whitepaper.io.txt
#   CloakCoin CLOAK whitepapers - whitepaper.io.txt
#   IBStoken IBS whitepapers - whitepaper.io.txt
#   Matrix AI Network MAN whitepapers - whitepaper.io.txt
#   Project Pai PAI whitepapers - whitepaper.io.txt
#   HEROcoin PLAY whitepapers - whitepaper.io.txt
#   Anchor ANCT whitepapers - whitepaper.io.txt
#   Dimecoin DIME whitepapers - whitepaper.io.txt
#   DeepOnion ONION whitepapers - whitepaper.io.txt
#   DAEX DAX whitepapers - whitepaper.io.txt
#   aiRight AIRI whitepapers - whitepaper.io.txt
#   Don-key DON whitepapers - whitepaper.io.txt
#   Florin XFL whitepapers - whitepaper.io.txt
#   Brother Music Platform BMP whitepapers - whitepaper.io.txt
#   EpiK Protocol EPK whitepapers - whitepaper.io.txt
#   Isiklar Coin ISIKC whitepapers - whitepaper.io.txt
#   CRYPTO20 C20 whitepapers - whitepaper.io.txt
#   Credits CS whitepapers - whitepaper.io.txt
#   CPChain CPC whitepapers - whitepaper.io.txt
#   Signata SATA whitepapers - whitepaper.io.txt
#   High Performance Blockchain HPB whitepapers - whitepaper.io.txt
#   Cindicator CND whitepapers - whitepaper.io.txt
#   ALLY ALY whitepapers - whitepaper.io.txt
#   PLATINCOIN PLC whitepapers - whitepaper.io.txt
#   TrueChain TRUE whitepapers - whitepaper.io.txt
#   Pillar PLR whitepapers - whitepaper.io.txt
#   Shirtum SHI whitepapers - whitepaper.io.txt
#   PERI Finance PERI whitepapers - whitepaper.io.txt
#   Chronicle XNL whitepapers - whitepaper.io.txt
#   Rangers Protocol RPG whitepapers - whitepaper.io.txt
#   CarVertical CV whitepapers - whitepaper.io.txt
#   RealFevr FEVR whitepapers - whitepaper.io.txt
#   Unistake UNISTAKE whitepapers - whitepaper.io.txt
#   CUTcoin CUT whitepapers - whitepaper.io.txt
#   42-coin 42 whitepapers - whitepaper.io.txt
#   Bitcoin Plus XBC whitepapers - whitepaper.io.txt
#   YOUChain YOU whitepapers - whitepaper.io.txt
#   Fortuna FOTA whitepapers - whitepaper.io.txt
#   Bean Cash - BitBean BITB whitepapers - whitepaper.io.txt
#   DRIFE DRF whitepapers - whitepaper.io.txt
#   GamesPad GMPD whitepapers - whitepaper.io.txt
#   Integritee Network TEER whitepapers - whitepaper.io.txt
#   Bread BRD whitepapers - whitepaper.io.txt
#   StakeNet XSN whitepapers - whitepaper.io.txt
#   LinkEye LET whitepapers - whitepaper.io.txt
#   Loser Coin LOWB whitepapers - whitepaper.io.txt
#   BlackHat BLKC whitepapers - whitepaper.io.txt
#   Baanx BXX whitepapers - whitepaper.io.txt
#   HTMLCOIN HTML whitepapers - whitepaper.io.txt
#   BlackCoin BLK whitepapers - whitepaper.io.txt
#   BonusCloud BXC whitepapers - whitepaper.io.txt
#   Digix Gold DGX whitepapers - whitepaper.io.txt
#   RigoBlock GRG whitepapers - whitepaper.io.txt
#   HempCoin THC whitepapers - whitepaper.io.txt
#   SmartCash SMART whitepapers - whitepaper.io.txt
#   Bismuth BIS whitepapers - whitepaper.io.txt
#   Levolution LEVL whitepapers - whitepaper.io.txt
#   THEKEY TKY whitepapers - whitepaper.io.txt
#   VIBE VIBE whitepapers - whitepaper.io.txt
#   BitcoinHD BHD whitepapers - whitepaper.io.txt
#   9D NFT COGI whitepapers - whitepaper.io.txt
#   YOYOW YOYOW whitepapers - whitepaper.io.txt
#   PlayFuel PLF whitepapers - whitepaper.io.txt
#   Odyssey OCN whitepapers - whitepaper.io.txt
#   PUTinCoin PUT whitepapers - whitepaper.io.txt
#   Humaniq HMQ whitepapers - whitepaper.io.txt
#   Medicalchain MTN whitepapers - whitepaper.io.txt
#   DAV Coin DAV whitepapers - whitepaper.io.txt
#   Hyve HYVE whitepapers - whitepaper.io.txt
#   DigitalNote XDN whitepapers - whitepaper.io.txt
#   BollyCoin BOLLY whitepapers - whitepaper.io.txt
#   HollyGold HGOLD whitepapers - whitepaper.io.txt
#   TenUp TUP whitepapers - whitepaper.io.txt
#   PayPie PPP whitepapers - whitepaper.io.txt
#   Litex LXT whitepapers - whitepaper.io.txt
#   LiquidApps DAPP whitepapers - whitepaper.io.txt
#   eXPerience Chain XPC whitepapers - whitepaper.io.txt
#   ATLANT ATL whitepapers - whitepaper.io.txt
#   Wall Street Games WSG whitepapers - whitepaper.io.txt
#   SaTT SATT whitepapers - whitepaper.io.txt
#   Paribus PBX whitepapers - whitepaper.io.txt
#   DMarket DMT whitepapers - whitepaper.io.txt
#   Tap XTP whitepapers - whitepaper.io.txt
#   PolkaWar PWAR whitepapers - whitepaper.io.txt
#   DAPS DAPS whitepapers - whitepaper.io.txt
#   W Green Pay WGP whitepapers - whitepaper.io.txt
#   DATA DTA whitepapers - whitepaper.io.txt
#   Huobi Pool Token HPT whitepapers - whitepaper.io.txt
#   OneRoot Network RNT whitepapers - whitepaper.io.txt
#   Swarm SWM whitepapers - whitepaper.io.txt
#   MediShares MDS whitepapers - whitepaper.io.txt
#   Hedget HGET whitepapers - whitepaper.io.txt
#   Lightstreams PHT whitepapers - whitepaper.io.txt
#   Zenfuse ZEFU whitepapers - whitepaper.io.txt
#   Pascal Coin PASC whitepapers - whitepaper.io.txt
#   ContentBox BOX whitepapers - whitepaper.io.txt
#   Primas PST whitepapers - whitepaper.io.txt
#   Substratum SUB whitepapers - whitepaper.io.txt
#   EVRYNET EVRY whitepapers - whitepaper.io.txt
#   Caspian CSP whitepapers - whitepaper.io.txt
#   DOSE DOSE whitepapers - whitepaper.io.txt
#   APIX APIX whitepapers - whitepaper.io.txt
#   GeoDB GEO whitepapers - whitepaper.io.txt
#   Wings WINGS whitepapers - whitepaper.io.txt
#   WePower WPR whitepapers - whitepaper.io.txt
#   OST OST whitepapers - whitepaper.io.txt
#   DinoX DNXC whitepapers - whitepaper.io.txt
#   Atlas Protocol ATP whitepapers - whitepaper.io.txt
#   CryptEx CRX whitepapers - whitepaper.io.txt
#   Aryacoin AYA whitepapers - whitepaper.io.txt
#   Hydrogen HYDRO whitepapers - whitepaper.io.txt
#   AtromG8 AG8 whitepapers - whitepaper.io.txt
#   APY.Finance APY whitepapers - whitepaper.io.txt
#   Tycoon TYC whitepapers - whitepaper.io.txt
#   Etherparty FUEL whitepapers - whitepaper.io.txt
#   AppCoins APPC whitepapers - whitepaper.io.txt
#   Bottos BTO whitepapers - whitepaper.io.txt
#   RealTract RET whitepapers - whitepaper.io.txt
#   Pacoca PACOCA whitepapers - whitepaper.io.txt
#   U Network UUU whitepapers - whitepaper.io.txt
#   Wolf Safe Poor People WSPP whitepapers - whitepaper.io.txt
#   Acute Angle Cloud AAC whitepapers - whitepaper.io.txt
#   BlockMason Credit Protocol BCPT whitepapers - whitepaper.io.txt
#   Bitcoin Rhodium XRC whitepapers - whitepaper.io.txt
#   Bitcoin Green BITG whitepapers - whitepaper.io.txt
#   NANJCOIN NANJ whitepapers - whitepaper.io.txt
#   Everex EVX whitepapers - whitepaper.io.txt
#   PlayChip PLA whitepapers - whitepaper.io.txt
#   Equal EQL whitepapers - whitepaper.io.txt
#   Remme REM whitepapers - whitepaper.io.txt
#   Falcon Project FNT whitepapers - whitepaper.io.txt
#   Ink INK whitepapers - whitepaper.io.txt
#   CoTrader COT whitepapers - whitepaper.io.txt
#   PRCY Coin PRCY whitepapers - whitepaper.io.txt
#   GoWithMi GMAT whitepapers - whitepaper.io.txt
#   Phore PHR whitepapers - whitepaper.io.txt
#   FantomStarter FS whitepapers - whitepaper.io.txt
#   Cyclub CYCLUB whitepapers - whitepaper.io.txt
#   IHT Real Estate Protocol IHT whitepapers - whitepaper.io.txt
#   MicroBitcoin MBC whitepapers - whitepaper.io.txt
#   EtherZero ETZ whitepapers - whitepaper.io.txt
#   Yee YEE whitepapers - whitepaper.io.txt
#   Zeepin ZPT whitepapers - whitepaper.io.txt
#   ULTRAIN UGAS whitepapers - whitepaper.io.txt
#   Qbao QBT whitepapers - whitepaper.io.txt
#   ODIN PROTOCOL ODIN whitepapers - whitepaper.io.txt
#   WeTrust TRST whitepapers - whitepaper.io.txt
#   My Master War MAT whitepapers - whitepaper.io.txt
#   Stox STX whitepapers - whitepaper.io.txt
#   Indorse IND whitepapers - whitepaper.io.txt
#   Gems GEM whitepapers - whitepaper.io.txt
#   Freicoin FRC whitepapers - whitepaper.io.txt
#   Motocoin MOTO whitepapers - whitepaper.io.txt
#   4THPILLAR TECHNOLOGIES FOUR whitepapers - whitepaper.io.txt
#   ShipChain SHIP whitepapers - whitepaper.io.txt
#   Enigma ENG whitepapers - whitepaper.io.txt
#   FuzeX FXT whitepapers - whitepaper.io.txt
#   Golden Goose GOLD whitepapers - whitepaper.io.txt
#   Origo OGO whitepapers - whitepaper.io.txt
#   Energo TSL whitepapers - whitepaper.io.txt
#   InvestFeed IFT whitepapers - whitepaper.io.txt
#   Zeusshield ZSC whitepapers - whitepaper.io.txt
#   Maecenas ART whitepapers - whitepaper.io.txt
#   Graft GRFT whitepapers - whitepaper.io.txt
#   LunchMoney LMY whitepapers - whitepaper.io.txt
#   x42 Protocol X42 whitepapers - whitepaper.io.txt
#   The Force Protocol FOR whitepapers - whitepaper.io.txt
#   AOK AOK whitepapers - whitepaper.io.txt
#   ETNA Network ETNA whitepapers - whitepaper.io.txt
#   Trinity Network Credit TNC whitepapers - whitepaper.io.txt
#   Jade Currency JADE whitepapers - whitepaper.io.txt
#   Shopping SPI whitepapers - whitepaper.io.txt
#   TERA TERA whitepapers - whitepaper.io.txt
#   LUXCoin LUX whitepapers - whitepaper.io.txt
#   Coldstack CLS whitepapers - whitepaper.io.txt
#   Smartshare SSP whitepapers - whitepaper.io.txt
#   Shadow Token SHDW whitepapers - whitepaper.io.txt
#   Asch XAS whitepapers - whitepaper.io.txt
#   Bata BTA whitepapers - whitepaper.io.txt
#   Stream Protocol STPL whitepapers - whitepaper.io.txt
#   SHIELD XSH whitepapers - whitepaper.io.txt
#   Bunicorn BUNI whitepapers - whitepaper.io.txt
#   uPlexa UPX whitepapers - whitepaper.io.txt
#   Catex Token CATT whitepapers - whitepaper.io.txt
#   INMAX INX whitepapers - whitepaper.io.txt
#   TrezarCoin TZC whitepapers - whitepaper.io.txt
#   Faceter FACE whitepapers - whitepaper.io.txt
#   Alphacat ACAT whitepapers - whitepaper.io.txt
#   MMOCoin MMO whitepapers - whitepaper.io.txt
#   Ancient Kingdom DOM whitepapers - whitepaper.io.txt
#   Lunyr LUN whitepapers - whitepaper.io.txt
#   pEOS PEOS whitepapers - whitepaper.io.txt
#   VEKTOR VEKTOR whitepapers - whitepaper.io.txt
#   Sportcash One SCONEX whitepapers - whitepaper.io.txt
#   MesChain MES whitepapers - whitepaper.io.txt
#   UpToken UP whitepapers - whitepaper.io.txt
#   Ritocoin RITO whitepapers - whitepaper.io.txt
#   Rate3 RTE whitepapers - whitepaper.io.txt
#   Ormeus Ecosystem ECO whitepapers - whitepaper.io.txt
#   COSMOCHAIN COSM whitepapers - whitepaper.io.txt
#   DecentBet DBET whitepapers - whitepaper.io.txt
#   Netrum NTR whitepapers - whitepaper.io.txt
#   Blockburn BURN whitepapers - whitepaper.io.txt
#   MyBit Token MYB whitepapers - whitepaper.io.txt
#   ALL BEST ICO ALLBI whitepapers - whitepaper.io.txt
#   Digitex Futures DGTX whitepapers - whitepaper.io.txt
#   MedicCoin MEDIC whitepapers - whitepaper.io.txt
#   Reward Hunters Token RHT whitepapers - whitepaper.io.txt
#   ArbitrageCT ARCT whitepapers - whitepaper.io.txt
#   Envion EVN whitepapers - whitepaper.io.txt
#   Arepacoin AREPA whitepapers - whitepaper.io.txt
#   8X8 PROTOCOL EXE whitepapers - whitepaper.io.txt
#   Blocktix TIX whitepapers - whitepaper.io.txt
#   Scholarship Coin SCHO whitepapers - whitepaper.io.txt
#   DragonVein DVC whitepapers - whitepaper.io.txt
#   SafeInsure SINS whitepapers - whitepaper.io.txt
#   BSClaunch BSL whitepapers - whitepaper.io.txt
#   Quantis Network QUAN whitepapers - whitepaper.io.txt
#   SCRIV NETWORK SCRIV whitepapers - whitepaper.io.txt
#   Kalata KALA whitepapers - whitepaper.io.txt
#   Kemacoin KEMA whitepapers - whitepaper.io.txt
#   DraftCoin DFT whitepapers - whitepaper.io.txt
#   Paypex PAYX whitepapers - whitepaper.io.txt
#   Sweetbridge SWC whitepapers - whitepaper.io.txt
#   Dynamite DYNMT whitepapers - whitepaper.io.txt
#   SafeCapital SCAP whitepapers - whitepaper.io.txt
#   SF Capital SFCP whitepapers - whitepaper.io.txt
#   The Currency Analytics TCAT whitepapers - whitepaper.io.txt
#   Entercoin ENTRC whitepapers - whitepaper.io.txt
#   CRDT CRDT whitepapers - whitepaper.io.txt
#   PonziCoin PONZI whitepapers - whitepaper.io.txt
#   ECC ECC whitepapers - whitepaper.io.txt
#   Aeron ARN whitepapers - whitepaper.io.txt
#   Blockport BPT whitepapers - whitepaper.io.txt
#   Crust CRU whitepapers - whitepaper.io.txt
#   Globiance GBEX whitepapers - whitepaper.io.txt
#   Silverway SLV whitepapers - whitepaper.io.txt
#   EXMR FDN EXMR whitepapers - whitepaper.io.txt
#   KICKICO KICK whitepapers - whitepaper.io.txt
#   LGO Exchange LGO whitepapers - whitepaper.io.txt
#   Polybius PLBT whitepapers - whitepaper.io.txt
#   Tierion TNT whitepapers - whitepaper.io.txt
#   ERON PROJECT ERON whitepapers - whitepaper.io.txt
#   LockTrip LOC whitepapers - whitepaper.io.txt
#   Alpha Finance Lab ALPHA whitepapers - whitepaper.io.txt
#   botXcoin BOTX whitepapers - whitepaper.io.txt
#   DECENT DCT whitepapers - whitepaper.io.txt
#   Bodhi BOT whitepapers - whitepaper.io.txt
#   Experience Points XP whitepapers - whitepaper.io.txt
#   BeeSwap BEE whitepapers - whitepaper.io.txt
#   EDC Blockchain EDC whitepapers - whitepaper.io.txt
#   NPCoin NPC whitepapers - whitepaper.io.txt
#   Bitpanda Ecosystem Token BEST whitepapers - whitepaper.io.txt
#   Chronobank TIME whitepapers - whitepaper.io.txt
#   Jointer JNTR whitepapers - whitepaper.io.txt
#   Certified Diamond Coin DPT whitepapers - whitepaper.io.txt
#   Mothership MSP whitepapers - whitepaper.io.txt
#   Ecoreal Estate ECOREAL whitepapers - whitepaper.io.txt
#   Hintchain HINT whitepapers - whitepaper.io.txt
#   CoinFLEX FLEX whitepapers - whitepaper.io.txt
#   VeriBlock VBK whitepapers - whitepaper.io.txt
#   Chain Games CHAIN whitepapers - whitepaper.io.txt
#   Eximchain EXC whitepapers - whitepaper.io.txt
#   Asia Coin ASIA whitepapers - whitepaper.io.txt
#   BLX BLX whitepapers - whitepaper.io.txt
#   Etheroll DICE whitepapers - whitepaper.io.txt
#   test CODE whitepapers - whitepaper.io.txt
#   Flexacoin FXC whitepapers - whitepaper.io.txt
#   Olympus Labs MOT whitepapers - whitepaper.io.txt
#   Hellenic Coin HNC whitepapers - whitepaper.io.txt
#   Aces ACES whitepapers - whitepaper.io.txt
#   MINDOL MIN whitepapers - whitepaper.io.txt
#   Alias ALIAS whitepapers - whitepaper.io.txt
#   Tidex Token TDX whitepapers - whitepaper.io.txt
#   TTC Protocol TTC whitepapers - whitepaper.io.txt
#   MyToken MT whitepapers - whitepaper.io.txt
#   FREE Coin FREE whitepapers - whitepaper.io.txt
#   INS Ecosystem INS whitepapers - whitepaper.io.txt
#   Horizon State HST whitepapers - whitepaper.io.txt
#   Insureum ISR whitepapers - whitepaper.io.txt
#   Ethereum Meta ETHM whitepapers - whitepaper.io.txt
#   Darcrus MER whitepapers - whitepaper.io.txt
#   Earneo RNO whitepapers - whitepaper.io.txt
#   PIBBLE PIB whitepapers - whitepaper.io.txt
#   Flits FLS whitepapers - whitepaper.io.txt
#   Axion AXN whitepapers - whitepaper.io.txt
#   INLOCK ILK whitepapers - whitepaper.io.txt
#   Maximine Coin MXM whitepapers - whitepaper.io.txt
#   ITAM Games ITAM whitepapers - whitepaper.io.txt
#   CasinoCoin CSC whitepapers - whitepaper.io.txt
#   UltrAlpha UAT whitepapers - whitepaper.io.txt
#   Codex CDEX whitepapers - whitepaper.io.txt
#   Bincentive BCNT whitepapers - whitepaper.io.txt
#   TILWIKI TLW whitepapers - whitepaper.io.txt
#   IDK IDK whitepapers - whitepaper.io.txt
#   Skillchain SKI whitepapers - whitepaper.io.txt
#   VARC VARC whitepapers - whitepaper.io.txt
#   BlockNoteX BNOX whitepapers - whitepaper.io.txt
#   ESR Coin ESRC whitepapers - whitepaper.io.txt
#   Etho Protocol ETHO whitepapers - whitepaper.io.txt
#   Tratok TRAT whitepapers - whitepaper.io.txt
#   Dapp Token DAPPT whitepapers - whitepaper.io.txt
#   Whole Network NODE whitepapers - whitepaper.io.txt
#   Bankroll Network BNKR whitepapers - whitepaper.io.txt
#   IXledger IXT whitepapers - whitepaper.io.txt
#   Litecash CASH whitepapers - whitepaper.io.txt
#   Oyster PRL whitepapers - whitepaper.io.txt
#   RAKUN RAKU whitepapers - whitepaper.io.txt
#   BNS Token BNS whitepapers - whitepaper.io.txt
#   Dionpay DION whitepapers - whitepaper.io.txt
#   BTS Chain BTSC whitepapers - whitepaper.io.txt
#   BiTToken BITT whitepapers - whitepaper.io.txt
#   IZIChain IZI whitepapers - whitepaper.io.txt
#   Funder One Capital FUNDX whitepapers - whitepaper.io.txt
#   Nodestats NS whitepapers - whitepaper.io.txt
#   DeFIRE CWAP whitepapers - whitepaper.io.txt
#   Jinbi Token JNB whitepapers - whitepaper.io.txt
#   CNNS CNNS whitepapers - whitepaper.io.txt
#   Fortress Lending FTS whitepapers - whitepaper.io.txt
#   BeforeCoinMarketCap BCMC1 whitepapers - whitepaper.io.txt
#   FrogeX FROGEX whitepapers - whitepaper.io.txt
#   Space Token SPACE whitepapers - whitepaper.io.txt
#   Shih Tzu SHIH whitepapers - whitepaper.io.txt
#   Copiosa Coin COP whitepapers - whitepaper.io.txt
#   Aquari AQUARI whitepapers - whitepaper.io.txt
#   Camp CAMP whitepapers - whitepaper.io.txt
#   Gold Secured Currency GSX whitepapers - whitepaper.io.txt
#   NiiFi NIIFI whitepapers - whitepaper.io.txt
#   LIFE LIFE whitepapers - whitepaper.io.txt
#   NAGA NGC whitepapers - whitepaper.io.txt
#   Metis MTS whitepapers - whitepaper.io.txt
#   Medicalveda MVEDA whitepapers - whitepaper.io.txt
#   BitOnyx BTNYX whitepapers - whitepaper.io.txt
#   PRIVATEUM INITIATIVE PRI whitepapers - whitepaper.io.txt
#   Aurix AUR whitepapers - whitepaper.io.txt
#   VKENAF VKNF whitepapers - whitepaper.io.txt
#   Moss Carbon Credit MCO2 whitepapers - whitepaper.io.txt
#   WallStreetBets DApp WSB whitepapers - whitepaper.io.txt
#   Moonlight Token MOONLIGHT whitepapers - whitepaper.io.txt
#   SOLBIT SBT whitepapers - whitepaper.io.txt
#   ARCS ARX whitepapers - whitepaper.io.txt
#   Joys Digital JOYS whitepapers - whitepaper.io.txt
#   Dexfin DXF whitepapers - whitepaper.io.txt
#   Kepler Network KMW whitepapers - whitepaper.io.txt
#   AMMYI Coin AMI whitepapers - whitepaper.io.txt
#   WiBX WBX whitepapers - whitepaper.io.txt
#   Counos X CCXX whitepapers - whitepaper.io.txt
#   CryptoXpress XPRESS whitepapers - whitepaper.io.txt
#   tGOLD TXAU whitepapers - whitepaper.io.txt
#   SorachanCoin SORA whitepapers - whitepaper.io.txt
#   ImpulseVen VEN whitepapers - whitepaper.io.txt
#   Kyrrex KRRX whitepapers - whitepaper.io.txt
#   NOSHIT NSH whitepapers - whitepaper.io.txt
#   dFund DFND whitepapers - whitepaper.io.txt
#   Ricnatum RCNT whitepapers - whitepaper.io.txt
#   Ctomorrow Platform CTP whitepapers - whitepaper.io.txt
#   KingDeFi KRW whitepapers - whitepaper.io.txt
#   ORIGYN Foundation OGY whitepapers - whitepaper.io.txt
#   Colizeum ZEUM whitepapers - whitepaper.io.txt
#   tBTC TBTC whitepapers - whitepaper.io.txt
#   PornVerse PVERSE whitepapers - whitepaper.io.txt
#   Time Raiders XPND whitepapers - whitepaper.io.txt
#   IOTEN IOTN whitepapers - whitepaper.io.txt
#   Sakaryaspor Token SKRY whitepapers - whitepaper.io.txt
#   Baby Shiba Inu BABYSHIBAINU whitepapers - whitepaper.io.txt
#   Intexcoin INTX whitepapers - whitepaper.io.txt
#   Colony Network Token CLNY whitepapers - whitepaper.io.txt
#   Eagle Token EAGLE whitepapers - whitepaper.io.txt
#   Artex ARTEX whitepapers - whitepaper.io.txt
#   TEN Wallet TENW whitepapers - whitepaper.io.txt
#   QuinCoin QIN whitepapers - whitepaper.io.txt
#   IX Swap IXS whitepapers - whitepaper.io.txt
#   IjasCoin IJC whitepapers - whitepaper.io.txt
#   888tron 888 whitepapers - whitepaper.io.txt
#   TokenBank TBANK whitepapers - whitepaper.io.txt
#   Overmoon OVM whitepapers - whitepaper.io.txt
#   Community Doge Coin CCDOGE whitepapers - whitepaper.io.txt
#   SafuYield Protocol SAFUYIELD whitepapers - whitepaper.io.txt
#   HUPAYX HPX whitepapers - whitepaper.io.txt
#   BitoPro Exchange Token BITO whitepapers - whitepaper.io.txt
#   Antalyaspor Token AKREP whitepapers - whitepaper.io.txt
#   ARTM ARTM whitepapers - whitepaper.io.txt
#   DragonBite BITE whitepapers - whitepaper.io.txt
#   Aerovek Aviation AERO whitepapers - whitepaper.io.txt
#   BlueArk BRK whitepapers - whitepaper.io.txt
#   holoride RIDE whitepapers - whitepaper.io.txt
#   Empire Token EMPIRE whitepapers - whitepaper.io.txt
#   Neopin NPT whitepapers - whitepaper.io.txt
#   Azit AZIT whitepapers - whitepaper.io.txt
#   DoKEN DOKEN whitepapers - whitepaper.io.txt
#   BurningMoon BM whitepapers - whitepaper.io.txt
#   Ziktalk ZIK whitepapers - whitepaper.io.txt
#   Nesten NIT whitepapers - whitepaper.io.txt
#   Predictcoin PRED whitepapers - whitepaper.io.txt
#   StorX Network SRX whitepapers - whitepaper.io.txt
#   Promise PROMISE whitepapers - whitepaper.io.txt
#   Pollux Coin POX whitepapers - whitepaper.io.txt
#   Nunu Spirits NNT whitepapers - whitepaper.io.txt
#   LaserEyes LSR whitepapers - whitepaper.io.txt
#   Rolaz Gold rGLD whitepapers - whitepaper.io.txt
#   Identity IDTT whitepapers - whitepaper.io.txt
#   Shibaverse VERSE whitepapers - whitepaper.io.txt
#   KittyCake KCAKE whitepapers - whitepaper.io.txt
#   Beldex BDX whitepapers - whitepaper.io.txt
#   VooVoo VOO whitepapers - whitepaper.io.txt
#   Parex PRX whitepapers - whitepaper.io.txt
#   JK Coin JK whitepapers - whitepaper.io.txt
#   Genshiro GENS whitepapers - whitepaper.io.txt
#   Green Climate World WGC whitepapers - whitepaper.io.txt
#   MoonTrustBSC MNTTBSC whitepapers - whitepaper.io.txt
#   MetaWear WEAR whitepapers - whitepaper.io.txt
#   MiniBTC MINIBTC whitepapers - whitepaper.io.txt
#   MOVE Network MOVD whitepapers - whitepaper.io.txt
#   ADAX ADAX whitepapers - whitepaper.io.txt
#   Traders coin TRDC whitepapers - whitepaper.io.txt
#   Mainston STON whitepapers - whitepaper.io.txt
#   Dequant DEQ whitepapers - whitepaper.io.txt
#   VEROX VRX whitepapers - whitepaper.io.txt
#   999 999 whitepapers - whitepaper.io.txt
#   Seascape Crowns CWS whitepapers - whitepaper.io.txt
#   Uno Re UNO whitepapers - whitepaper.io.txt
#   Toko Token TKO whitepapers - whitepaper.io.txt
#   ROONEX RNX whitepapers - whitepaper.io.txt
#   JPY Coin v1 JPYC whitepapers - whitepaper.io.txt
#   Nominex NMX whitepapers - whitepaper.io.txt
#   Ara Blocks ARA whitepapers - whitepaper.io.txt
#   Flash FLASH whitepapers - whitepaper.io.txt
#   ProSwap PROS whitepapers - whitepaper.io.txt
#   Libra LIBRA whitepapers - whitepaper.io.txt
#   MassGrid MGD whitepapers - whitepaper.io.txt
#   Vitae VITAE whitepapers - whitepaper.io.txt
#   Corgidoge CORGI whitepapers - whitepaper.io.txt
#   CloudCoin CC whitepapers - whitepaper.io.txt
#   BeFaster Holder Token BFHT whitepapers - whitepaper.io.txt
#   My Crypto Play MCP whitepapers - whitepaper.io.txt
#   Dropil DROP whitepapers - whitepaper.io.txt
#   Finance.Vote FVT whitepapers - whitepaper.io.txt
#   Ferret Token FERRET whitepapers - whitepaper.io.txt
#   Grexie GREX whitepapers - whitepaper.io.txt
#   Like2like LikeToken whitepapers - whitepaper.io.txt
#   ViptoCoin ViptoCoin whitepapers - whitepaper.io.txt
#   Microtuber MCT whitepapers - whitepaper.io.txt
#   Safegem GEMS whitepapers - whitepaper.io.txt
#   KILT Protocol KILT whitepapers - whitepaper.io.txt
#   Archethic UCO whitepapers - whitepaper.io.txt
#   Electra ECA whitepapers - whitepaper.io.txt
#   Storiqa STQ whitepapers - whitepaper.io.txt
#   Truebit TRU whitepapers - whitepaper.io.txt
#   UgChain UGC whitepapers - whitepaper.io.txt
#   Zebi ZCO whitepapers - whitepaper.io.txt
#   Zipper ZIP whitepapers - whitepaper.io.txt
#   Hithotx HITX whitepapers - whitepaper.io.txt
#   JasmyCoin JASMY whitepapers - whitepaper.io.txt
#   LUXO LUXO whitepapers - whitepaper.io.txt
#   Tarush TAS whitepapers - whitepaper.io.txt
#   FileStar STAR whitepapers - whitepaper.io.txt
#   Pura PURA whitepapers - whitepaper.io.txt
#   Peerplays PPY whitepapers - whitepaper.io.txt
#   Busy DAO BUSY whitepapers - whitepaper.io.txt
#   Hyperspace XSC whitepapers - whitepaper.io.txt
#   Datawallet DXT whitepapers - whitepaper.io.txt
#   SYL SYL whitepapers - whitepaper.io.txt
#   Radium RADS whitepapers - whitepaper.io.txt
#   Rielcoin RIC whitepapers - whitepaper.io.txt
#   Morpher MPH whitepapers - whitepaper.io.txt
#   Honey HNY whitepapers - whitepaper.io.txt
#   Accumulate ACME whitepapers - whitepaper.io.txt
#   Olyverse OLY whitepapers - whitepaper.io.txt
#   Bogged BOG whitepapers - whitepaper.io.txt
#   Clipper Coin CCCX whitepapers - whitepaper.io.txt
#   Matchpool GUP whitepapers - whitepaper.io.txt
#   APIS APIS whitepapers - whitepaper.io.txt
#   Robotina ROX whitepapers - whitepaper.io.txt
#   HexxCoin HXX whitepapers - whitepaper.io.txt
#   GreenPower GRN whitepapers - whitepaper.io.txt
#   Bitbook Gambling BXK whitepapers - whitepaper.io.txt
#   DATACHAIN FOUNDATION (DC) DC whitepapers - whitepaper.io.txt
#   QunQun QUN whitepapers - whitepaper.io.txt
#   MoonLift Capital MLTPX whitepapers - whitepaper.io.txt
#   Catoshi CZATS whitepapers - whitepaper.io.txt
#   Linkey LKY whitepapers - whitepaper.io.txt
#   Bitgert BRISE whitepapers - whitepaper.io.txt
#   NoLimitCoin NLC2 whitepapers - whitepaper.io.txt
#   Bitcoiin2Gen B2G whitepapers - whitepaper.io.txt
#   BrahmaOS BRM whitepapers - whitepaper.io.txt
#   Solster Finance STR whitepapers - whitepaper.io.txt
#   PL^Gnet PLUG whitepapers - whitepaper.io.txt
#   BitBay BAY whitepapers - whitepaper.io.txt
#   Esportbits HLT whitepapers - whitepaper.io.txt
#   Cloudbric CLB whitepapers - whitepaper.io.txt
#   Vega Protocol VEGA whitepapers - whitepaper.io.txt
#   Game Ace Token GAT whitepapers - whitepaper.io.txt
#   Gravity Finance GFI whitepapers - whitepaper.io.txt
#   One Basis OBS whitepapers - whitepaper.io.txt
#   Starlink STARL whitepapers - whitepaper.io.txt
#   Bitcoin Asia BTCA whitepapers - whitepaper.io.txt
#   delta.theta DLTA whitepapers - whitepaper.io.txt
#   Tao XTO whitepapers - whitepaper.io.txt
#   Nework NKC whitepapers - whitepaper.io.txt
#   Annex Finance ANN whitepapers - whitepaper.io.txt
#   STK STK whitepapers - whitepaper.io.txt
#   Buying.com BUY whitepapers - whitepaper.io.txt
#   Bitcoin Turbo Koin BTK whitepapers - whitepaper.io.txt
#   Little Angry Bunny v2 LAB v2 whitepapers - whitepaper.io.txt
#   Mirrored iShares Silver Trust MSLV whitepapers - whitepaper.io.txt
#   MineBee MB whitepapers - whitepaper.io.txt
#   BHO Network BHO whitepapers - whitepaper.io.txt
#   Affinity AFNTY whitepapers - whitepaper.io.txt
#   Blockius BLOS whitepapers - whitepaper.io.txt
#   TRDGtoken (ETH) TRDG whitepapers - whitepaper.io.txt
#   CryptoArt.Ai CART whitepapers - whitepaper.io.txt
#   SimpleDEFi $EASY whitepapers - whitepaper.io.txt
#   FibSWAP DEx FIBO whitepapers - whitepaper.io.txt
#   Vaulty VLTY whitepapers - whitepaper.io.txt
#   SingularityNET AGI whitepapers - whitepaper.io.txt
#   KalyCoin KalyCoin whitepapers - whitepaper.io.txt
#   Shivom OMX whitepapers - whitepaper.io.txt
#   BABEEZ BABEEZ whitepapers - whitepaper.io.txt
#   Nezha ($NEZ) Nezha ($NEZ) whitepapers - whitepaper.io.txt
#   Gold Bits Coin GBC whitepapers - whitepaper.io.txt
#   Yap Stone YAP whitepapers - whitepaper.io.txt
#   Lucky Seven LST whitepapers - whitepaper.io.txt
#   Lightcoin LHC whitepapers - whitepaper.io.txt
#   Jax.Network WJXN whitepapers - whitepaper.io.txt
#   Canlead CAND whitepapers - whitepaper.io.txt
#   Shift SHIFT whitepapers - whitepaper.io.txt
#   Boolberry BBR whitepapers - whitepaper.io.txt
#   Tigereum TIG whitepapers - whitepaper.io.txt
#   StarSharks (SSS) SSS whitepapers - whitepaper.io.txt
#   IOI Token IOI whitepapers - whitepaper.io.txt
#   GAPS GAP whitepapers - whitepaper.io.txt
#   HitBTC Token HIT whitepapers - whitepaper.io.txt
#   Wixlar WIX whitepapers - whitepaper.io.txt
#   Fanspel FAN whitepapers - whitepaper.io.txt
#   TaTaTu TTU whitepapers - whitepaper.io.txt
#   Blackmoon BMC whitepapers - whitepaper.io.txt
#   Wowoo WWB whitepapers - whitepaper.io.txt
#   TAGZ5 TAGZ5 whitepapers - whitepaper.io.txt
#   Tenshi TENSHI whitepapers - whitepaper.io.txt
#   Tune.FM JAM whitepapers - whitepaper.io.txt
#   Biconomy Exchange Token BIT whitepapers - whitepaper.io.txt
#   NuBits USNBT whitepapers - whitepaper.io.txt
#   COSS COSS whitepapers - whitepaper.io.txt
#   Light DeFi LIGHT whitepapers - whitepaper.io.txt
#   BetterBetting BETR whitepapers - whitepaper.io.txt
#   ZVCHAIN ZVC whitepapers - whitepaper.io.txt
#   NFTY Token NFTY whitepapers - whitepaper.io.txt
#   DenDomains DDN whitepapers - whitepaper.io.txt
#   bloXmove Token BLXM whitepapers - whitepaper.io.txt
#   Bankex BKX whitepapers - whitepaper.io.txt
#   Noah Coin NOAH whitepapers - whitepaper.io.txt
#   Keeps Coin KVERSE whitepapers - whitepaper.io.txt
#   Shiryo SHIRYO whitepapers - whitepaper.io.txt
#   Divi DIVX whitepapers - whitepaper.io.txt
#   Infomatix INFO whitepapers - whitepaper.io.txt
#   Insolar XNS whitepapers - whitepaper.io.txt
#   Connector Coin CNCTR (Polygon) whitepapers - whitepaper.io.txt
#   Redemption Token RDTN whitepapers - whitepaper.io.txt
#   SB GROUP SB whitepapers - whitepaper.io.txt
#   ALQO ALQO whitepapers - whitepaper.io.txt
#   Fruits null whitepapers - whitepaper.io.txt
#   Largo Coin LRG whitepapers - whitepaper.io.txt
#   Shibnobi SHINJA whitepapers - whitepaper.io.txt
#   Somnium SOM whitepapers - whitepaper.io.txt
#   Open Rights Exchange ORE whitepapers - whitepaper.io.txt
#   Frostbyte null whitepapers - whitepaper.io.txt
#   Guild of Guardians GOG whitepapers - whitepaper.io.txt
#   Akt.io AKTIO whitepapers - whitepaper.io.txt
#   ProChain PRA whitepapers - whitepaper.io.txt
#   NFT Champions CHAMP whitepapers - whitepaper.io.txt
#   Indigo Protocol null whitepapers - whitepaper.io.txt
#   Leonicorn Swap ( LEON ) LEON whitepapers - whitepaper.io.txt
#   LinkSync SYNC whitepapers - whitepaper.io.txt
#   Universa UTNP whitepapers - whitepaper.io.txt
#   CurveUSD null whitepapers - whitepaper.io.txt
#   Vagabond VGO whitepapers - whitepaper.io.txt
#   SelfSell SSC whitepapers - whitepaper.io.txt
#   Ivy IVY whitepapers - whitepaper.io.txt
#   Ticko TICK whitepapers - whitepaper.io.txt
#   Ducks Finance DCKS whitepapers - whitepaper.io.txt
#   TheDopeDAO DOPE whitepapers - whitepaper.io.txt
#   99DEFI.NETWORK 99DEFI whitepapers - whitepaper.io.txt
#   MobileGo MGO whitepapers - whitepaper.io.txt
#   MausCoin France whitepapers - whitepaper.io.txt
#   Snap Token SNAP whitepapers - whitepaper.io.txt
#   Zonex Exchange ZXT whitepapers - whitepaper.io.txt
#   IDEAS IDS whitepapers - whitepaper.io.txt
#   Dublr DUBLR whitepapers - whitepaper.io.txt
#   Portuma POR whitepapers - whitepaper.io.txt
#   Jurat Jurat whitepapers - whitepaper.io.txt
#   Insight Chain INB whitepapers - whitepaper.io.txt
#   AEToken AET whitepapers - whitepaper.io.txt
#   Clinic Spectrum null whitepapers - whitepaper.io.txt
#   Launchpad TG DAO 3.0 TGDAO whitepapers - whitepaper.io.txt
#   Ghost null whitepapers - whitepaper.io.txt
#   BHAX Token BHAX whitepapers - whitepaper.io.txt
#   Latium LATX whitepapers - whitepaper.io.txt
#   GEARZ SOLANA whitepapers - whitepaper.io.txt
#   Behodler EYE is the governance token Scarcity (SCX) is the Liquidity Token Flan (FLN) is a reward token issued by a token migration yield farm, Limbo. whitepapers - whitepaper.io.txt
#   DogeBNB.org DOGEBNB whitepapers - whitepaper.io.txt
#   META REVOLUTION WORLD - REVOLD GAME REVOLD Coin whitepapers - whitepaper.io.txt
#   Bozkurt Token BT whitepapers - whitepaper.io.txt
#   BitShiba SHIBA whitepapers - whitepaper.io.txt
#   Lxveworld ETH whitepapers - whitepaper.io.txt
#   BaconCoin BACON whitepapers - whitepaper.io.txt
#   HOME SCHOOL AND SPORTS YOUTH STARS USD whitepapers - whitepaper.io.txt
#   Wizarre Scroll SCRL whitepapers - whitepaper.io.txt
#   CryptoBull 168000000 whitepapers - whitepaper.io.txt
#   Komainu 0xfe88c952dfd9595f266bae053daaac411ccfaf07 whitepapers - whitepaper.io.txt
#   Axl Inu AXL whitepapers - whitepaper.io.txt
#   KolisCoin Network KolisCoin(KOL) whitepapers - whitepaper.io.txt
#   Kitty Coin Solana KITTY whitepapers - whitepaper.io.txt
#   Outer Ring MMO (GQ) GQ whitepapers - whitepaper.io.txt
#   MOAC MOAC whitepapers - whitepaper.io.txt
#   Rock (GBX Limited) RKT whitepapers - whitepaper.io.txt
#   Gari Network GARI whitepapers - whitepaper.io.txt
#   Uniform Fiscal Object UFO whitepapers - whitepaper.io.txt
#   Piccolo Inu PINU whitepapers - whitepaper.io.txt
#   LoyalCoin LYL whitepapers - whitepaper.io.txt
#   MarsX MX whitepapers - whitepaper.io.txt
#   Santa Coin SANTA whitepapers - whitepaper.io.txt
#   Apex CPX whitepapers - whitepaper.io.txt
#   Omax Coin OMAX whitepapers - whitepaper.io.txt
#   Phoenix PHB whitepapers - whitepaper.io.txt
#   STOA Network STA whitepapers - whitepaper.io.txt
#   Heros Token HEROS whitepapers - whitepaper.io.txt
#   Bulwark BWK whitepapers - whitepaper.io.txt
#   Cultiplan(CTPL) CTPL whitepapers - whitepaper.io.txt
#   Rise RISE whitepapers - whitepaper.io.txt
#   XIDR XIDR whitepapers - whitepaper.io.txt
#   Storm STORM whitepapers - whitepaper.io.txt
#   LocalTrade LTT whitepapers - whitepaper.io.txt
#   PumpETH PETH whitepapers - whitepaper.io.txt
#   Linda LINDA whitepapers - whitepaper.io.txt
#   Denarius D whitepapers - whitepaper.io.txt
#   PLT PLT whitepapers - whitepaper.io.txt
#   PeaceTokenFinance PET whitepapers - whitepaper.io.txt
#   A4 Finance A4 whitepapers - whitepaper.io.txt
#   Playkey PKT whitepapers - whitepaper.io.txt
#   Monaco MCO whitepapers - whitepaper.io.txt
#   AstroSpaces.io SPACES whitepapers - whitepaper.io.txt
#   Weboo Swap WEBOO whitepapers - whitepaper.io.txt
#   United Traders Token UTT whitepapers - whitepaper.io.txt
#   War Bond Token WBOND whitepapers - whitepaper.io.txt
#   Felix FLX whitepapers - whitepaper.io.txt
#   AppleSwap APPLE whitepapers - whitepaper.io.txt
#   Survive SURV whitepapers - whitepaper.io.txt
#   Nexty NTY whitepapers - whitepaper.io.txt
#   PACcoin $PAC whitepapers - whitepaper.io.txt
#   Cornatto CNC whitepapers - whitepaper.io.txt
#   MonoMoney MONO whitepapers - whitepaper.io.txt
#   Phoenix Global [old] PHX whitepapers - whitepaper.io.txt
#   ODEM ODE whitepapers - whitepaper.io.txt
#   SEOR Network SEOR whitepapers - whitepaper.io.txt
#   Punk.Network PUNK whitepapers - whitepaper.io.txt
#   Crystal Powder CP whitepapers - whitepaper.io.txt
#   Diabolo DCASH whitepapers - whitepaper.io.txt
#   TAFToken TAF whitepapers - whitepaper.io.txt
#   Japan Content Token JCT whitepapers - whitepaper.io.txt
#   EurocoinToken ECTE whitepapers - whitepaper.io.txt
#   HEADLINE HDL whitepapers - whitepaper.io.txt
#   DogeFather FATHER whitepapers - whitepaper.io.txt
#   Shibrobi SHIBORG whitepapers - whitepaper.io.txt
#   InnovaMinex MINX whitepapers - whitepaper.io.txt
#   SpectreSecurityCoin XSPC whitepapers - whitepaper.io.txt
#   SOMDEJ SDC whitepapers - whitepaper.io.txt
#   B2BX B2B whitepapers - whitepaper.io.txt
#   Travel Care TRAVEL whitepapers - whitepaper.io.txt
#   MinexCoin MNX whitepapers - whitepaper.io.txt
#   Ascendex BTMX whitepapers - whitepaper.io.txt
#   Hive HIVE whitepapers - whitepaper.io.txt
#   Linear LINA whitepapers - whitepaper.io.txt
#   GINcoin GIN whitepapers - whitepaper.io.txt
#   Torex TOR whitepapers - whitepaper.io.txt
#   Blue Baikal BBC whitepapers - whitepaper.io.txt
#   Sugarchain SUGAR whitepapers - whitepaper.io.txt
#   Axis DeFi AXIS whitepapers - whitepaper.io.txt
#   Morpheus.Network MNW whitepapers - whitepaper.io.txt
#   INO COIN INO whitepapers - whitepaper.io.txt
#   Civitas CIV whitepapers - whitepaper.io.txt
#   MCF Token MCF whitepapers - whitepaper.io.txt
#   Nano NANO whitepapers - whitepaper.io.txt
#   Hshare (Hcash) HSR whitepapers - whitepaper.io.txt
#   STP STPT whitepapers - whitepaper.io.txt
#   CS9 CS9 whitepapers - whitepaper.io.txt
#   Sqfcoin SQFCOIN whitepapers - whitepaper.io.txt
#   Havven HAV whitepapers - whitepaper.io.txt
#   Mt Pelerin Shares MPS whitepapers - whitepaper.io.txt
#   Hacken Token HAI whitepapers - whitepaper.io.txt
#   BGOGO BGG whitepapers - whitepaper.io.txt
#   BlackPearl Token BPLC whitepapers - whitepaper.io.txt
#   Tokamak Network TON whitepapers - whitepaper.io.txt
#   Bloom BLT whitepapers - whitepaper.io.txt
#   ATN ATN whitepapers - whitepaper.io.txt
#   Nucleus Vision NCASH whitepapers - whitepaper.io.txt
#   MoneroV XMV whitepapers - whitepaper.io.txt
#   Cryptoindex.com 100 CIX100 whitepapers - whitepaper.io.txt
#   Sucrecoin XSR whitepapers - whitepaper.io.txt
#   XBIT XBT whitepapers - whitepaper.io.txt
#   DIMCOIN DIM whitepapers - whitepaper.io.txt
#   Documentchain DMS whitepapers - whitepaper.io.txt
#   KOK KOK whitepapers - whitepaper.io.txt
#   Scopuly SCOP whitepapers - whitepaper.io.txt
#   Alchemy ACOIN whitepapers - whitepaper.io.txt
#   Decurian ECU whitepapers - whitepaper.io.txt
#   Datum DAT whitepapers - whitepaper.io.txt
#   RioDeFi RFUEL whitepapers - whitepaper.io.txt
#   Effect Network EFX whitepapers - whitepaper.io.txt
#   Footballcoin (XFC) XFC whitepapers - whitepaper.io.txt
#   Elastic XEL whitepapers - whitepaper.io.txt
#   Vivid Labs VID whitepapers - whitepaper.io.txt
#   BITICA COIN BDCC whitepapers - whitepaper.io.txt
#   AMARK XAC whitepapers - whitepaper.io.txt
#   PressOne PRS whitepapers - whitepaper.io.txt
#   Qbic QBIC whitepapers - whitepaper.io.txt
#   UCX UCX whitepapers - whitepaper.io.txt
#   ZrCoin ZRC whitepapers - whitepaper.io.txt
#   Paxos Standard Token PAX whitepapers - whitepaper.io.txt
#   PROXI CREDIT whitepapers - whitepaper.io.txt
#   Jibrel Network JNT whitepapers - whitepaper.io.txt
#   CarBlock CAR whitepapers - whitepaper.io.txt
#   BitRent RNTB whitepapers - whitepaper.io.txt
#   Bitspark ZEPH whitepapers - whitepaper.io.txt
#   Golden Goal GDG whitepapers - whitepaper.io.txt
#   WAX WAX whitepapers - whitepaper.io.txt
#   Daneel DAN whitepapers - whitepaper.io.txt
#   ExchangeCoin EXCC whitepapers - whitepaper.io.txt
#   Curio CUR whitepapers - whitepaper.io.txt
#   Duzce Token DUZCE whitepapers - whitepaper.io.txt
#   WOM Protocol WOM whitepapers - whitepaper.io.txt
#   FYDcoin FYD whitepapers - whitepaper.io.txt
#   HITOP HITOP whitepapers - whitepaper.io.txt
#   Goons of Balatroon GOB whitepapers - whitepaper.io.txt
#   Blocksafe - Triggers TRIG whitepapers - whitepaper.io.txt
#   Homeros HMR whitepapers - whitepaper.io.txt
#   Ormeus Cash OMC whitepapers - whitepaper.io.txt
#   STEPN GMT whitepapers - whitepaper.io.txt
#   GTI Token GTI whitepapers - whitepaper.io.txt
#   HI HI whitepapers - whitepaper.io.txt
#   Good Person Coin GPCX whitepapers - whitepaper.io.txt
#   Gulf Coin GULF whitepapers - whitepaper.io.txt
#   H2O Securities H2ON whitepapers - whitepaper.io.txt
#   Karma KRM whitepapers - whitepaper.io.txt
#   Icel Idman Yurdu Token MIY whitepapers - whitepaper.io.txt
#   Idavoll DAO IDV whitepapers - whitepaper.io.txt
#   Blockstack STX whitepapers - whitepaper.io.txt
#   Kingaru KRU whitepapers - whitepaper.io.txt
#   Ethos ETHOS whitepapers - whitepaper.io.txt
#   Kishimoto Kishimoto whitepapers - whitepaper.io.txt
#   Hub - Human Trust Protocol HUB whitepapers - whitepaper.io.txt
#   Supreme Finance HYPE whitepapers - whitepaper.io.txt
#   Jetset JTS whitepapers - whitepaper.io.txt
#   Nectar NEC whitepapers - whitepaper.io.txt
#   BiFi BIFI whitepapers - whitepaper.io.txt
#   Kashima Inu SHIMA whitepapers - whitepaper.io.txt
#   Ki XKI whitepapers - whitepaper.io.txt
#   KISSAN KSN whitepapers - whitepaper.io.txt
#   Hulk Inu HULK whitepapers - whitepaper.io.txt
#   whitepaper null whitepapers - whitepaper.io.txt
#   BlockDag null whitepapers - whitepaper.io.txt
#   Aptos null whitepapers - whitepaper.io.txt
#   Bitcoin BTC whitepapers - whitepaper.io.txt
#   Ethereum ETH whitepapers - whitepaper.io.txt
#   Tether USDT whitepapers - whitepaper.io.txt
#   USD Coin USDC whitepapers - whitepaper.io.txt
#   Binance BNB whitepapers - whitepaper.io.txt
#   Ripple XRP whitepapers - whitepaper.io.txt
#   Cardano ADA whitepapers - whitepaper.io.txt
#   Solana SOL whitepapers - whitepaper.io.txt
#   Dogecoin DOGE whitepapers - whitepaper.io.txt
#   Matic Network MATIC whitepapers - whitepaper.io.txt
#   Polkadot DOT whitepapers - whitepaper.io.txt
#   SHIBA INU SHIB whitepapers - whitepaper.io.txt
#   Dai DAI whitepapers - whitepaper.io.txt
#   TRON TRX whitepapers - whitepaper.io.txt
#   Avalanche AVAX whitepapers - whitepaper.io.txt
#   LEOcoin LEO whitepapers - whitepaper.io.txt
#   Wrapped Bitcoin WBTC whitepapers - whitepaper.io.txt
#   UNUS SED LEO LEO whitepapers - whitepaper.io.txt
#   Uniswap UNI whitepapers - whitepaper.io.txt
#   Cosmos ATOM whitepapers - whitepaper.io.txt
#   Litecoin LTC whitepapers - whitepaper.io.txt
#   Chainlink LINK whitepapers - whitepaper.io.txt
#   FTX Token FTT whitepapers - whitepaper.io.txt
#   Crypto.com Chain CRO whitepapers - whitepaper.io.txt
#   Stellar XLM whitepapers - whitepaper.io.txt
#   Flow (Dapper Labs) FLOW whitepapers - whitepaper.io.txt
#   VeChain VET whitepapers - whitepaper.io.txt
#   Filecoin FIL whitepapers - whitepaper.io.txt
#   Chiliz CHZ whitepapers - whitepaper.io.txt
#   Internet Computer ICP whitepapers - whitepaper.io.txt
#   Tezos XTZ whitepapers - whitepaper.io.txt
#   Decentraland MANA whitepapers - whitepaper.io.txt
#   Hedera Hashgraph HBAR whitepapers - whitepaper.io.txt
#   The Sandbox SAND whitepapers - whitepaper.io.txt
#   Quant QNT whitepapers - whitepaper.io.txt
#   EOS EOS whitepapers - whitepaper.io.txt
#   Theta Token THETA whitepapers - whitepaper.io.txt
#   Elrond EGLD whitepapers - whitepaper.io.txt
#   Aave AAVE whitepapers - whitepaper.io.txt
#   KuCoin Shares KCS whitepapers - whitepaper.io.txt
#   Zcash ZEC whitepapers - whitepaper.io.txt
#   BitTorrent BTT whitepapers - whitepaper.io.txt
#   IOTA MIOTA whitepapers - whitepaper.io.txt
#   Synthetix Network Token SNX whitepapers - whitepaper.io.txt
#   Klaytn KLAY whitepapers - whitepaper.io.txt
#   Maker MKR whitepapers - whitepaper.io.txt
#   Gemini Dollar GUSD whitepapers - whitepaper.io.txt
#   Helium HNT whitepapers - whitepaper.io.txt
#   Neo NEO whitepapers - whitepaper.io.txt
#   Fantom FTM whitepapers - whitepaper.io.txt
#   PAX Gold PAXG whitepapers - whitepaper.io.txt
#   THORChain RUNE whitepapers - whitepaper.io.txt
#   Nexo NEXO whitepapers - whitepaper.io.txt
#   Curve DAO Token CRV whitepapers - whitepaper.io.txt
#   Enjin Coin ENJ whitepapers - whitepaper.io.txt
#   Dash DASH whitepapers - whitepaper.io.txt
#   Basic Attention Token BAT whitepapers - whitepaper.io.txt
#   Waves WAVES whitepapers - whitepaper.io.txt
#   Zilliqa ZIL whitepapers - whitepaper.io.txt
#   Ravencoin RVN whitepapers - whitepaper.io.txt
#   Compound COMP whitepapers - whitepaper.io.txt
#   Loopring LRC whitepapers - whitepaper.io.txt
#   Celsius CEL whitepapers - whitepaper.io.txt
#   1inch 1INCH whitepapers - whitepaper.io.txt
#   NEM XEM whitepapers - whitepaper.io.txt
#   Holo HOT whitepapers - whitepaper.io.txt
#   Ankr Network ANKR whitepapers - whitepaper.io.txt
#   Terra LUNA whitepapers - whitepaper.io.txt
#   Arweave AR whitepapers - whitepaper.io.txt
#   XinFin Network XDC whitepapers - whitepaper.io.txt
#   Gnosis GNO whitepapers - whitepaper.io.txt
#   Qtum QTUM whitepapers - whitepaper.io.txt
#   SafeMoon SAFEMOON whitepapers - whitepaper.io.txt
#   Kyber Network KNC whitepapers - whitepaper.io.txt
#   LINK LN whitepapers - whitepaper.io.txt
#   IoTeX IOTX whitepapers - whitepaper.io.txt
#   Golem GLM whitepapers - whitepaper.io.txt
#   Theta Fuel TFUEL whitepapers - whitepaper.io.txt
#   Rocket Pool RPL whitepapers - whitepaper.io.txt
#   Reserve Rights RSR whitepapers - whitepaper.io.txt
#   OMG Network OMG whitepapers - whitepaper.io.txt
#   Harmony ONE whitepapers - whitepaper.io.txt
#   IOStoken IOST whitepapers - whitepaper.io.txt
#   ZEON ZEON whitepapers - whitepaper.io.txt
#   Chain XCN whitepapers - whitepaper.io.txt
#   Balancer BAL whitepapers - whitepaper.io.txt
#   0x ZRX whitepapers - whitepaper.io.txt
#   BORA BORA whitepapers - whitepaper.io.txt
#   Symbol XYM whitepapers - whitepaper.io.txt
#   ICON ICX whitepapers - whitepaper.io.txt
#   ZenCash ZEN whitepapers - whitepaper.io.txt
#   ABBC Foundation ABBC whitepapers - whitepaper.io.txt
#   Serum SRM whitepapers - whitepaper.io.txt
#   Ontology ONT whitepapers - whitepaper.io.txt
# ...
#   HedgeTrade HEDG whitepapers - whitepaper.io.txt
#   SUN SUN whitepapers - whitepaper.io.txt
#   Centrality CENNZ whitepapers - whitepaper.io.txt
#   Celo Dollar CUSD whitepapers - whitepaper.io.txt
#   MovieBloc MBL whitepapers - whitepaper.io.txt
#   Hifi Finance MFT whitepapers - whitepaper.io.txt
#   CONUN CON whitepapers - whitepaper.io.txt
#   SOMESING SSX whitepapers - whitepaper.io.txt
#   ThunderCore TT whitepapers - whitepaper.io.txt
#   Concordium CCD whitepapers - whitepaper.io.txt
#   Melon MLN whitepapers - whitepaper.io.txt
#   Polkastarter POLS whitepapers - whitepaper.io.txt
#   Dero DERO whitepapers - whitepaper.io.txt
#   Dusk Network DUSK whitepapers - whitepaper.io.txt
#   Chainbing CBG whitepapers - whitepaper.io.txt
#   Verasity VRA whitepapers - whitepaper.io.txt
#   Sport and Leisure SNL whitepapers - whitepaper.io.txt
#   Mines of Dalarnia DAR whitepapers - whitepaper.io.txt
#   Ampleforth AMPL whitepapers - whitepaper.io.txt
#   GXChain GXC whitepapers - whitepaper.io.txt
#   Neblio NEBL whitepapers - whitepaper.io.txt
#   Strike STRK whitepapers - whitepaper.io.txt
#   Phala.Network PHA whitepapers - whitepaper.io.txt
#   dKargo DKA whitepapers - whitepaper.io.txt
#   Yield Guild Games YGG whitepapers - whitepaper.io.txt
#   Cocos-BCX COCOS whitepapers - whitepaper.io.txt
#   Band Protocol BAND whitepapers - whitepaper.io.txt
#   TomoChain TOMO whitepapers - whitepaper.io.txt
#   smARTOFGIVING AOG whitepapers - whitepaper.io.txt
#   Klever KLV whitepapers - whitepaper.io.txt
#   Qcash QC whitepapers - whitepaper.io.txt
#   SafePal SFP whitepapers - whitepaper.io.txt
#   Wanchain WAN whitepapers - whitepaper.io.txt
#   BitShares BTS whitepapers - whitepaper.io.txt
#   Super Zero SERO whitepapers - whitepaper.io.txt
#   Carry CRE whitepapers - whitepaper.io.txt
#   LINA LINA whitepapers - whitepaper.io.txt
#   Komodo KMD whitepapers - whitepaper.io.txt
#   Gods Unchained GODS whitepapers - whitepaper.io.txt
#   AIOZ Network AIOZ whitepapers - whitepaper.io.txt
#   PlatON LAT whitepapers - whitepaper.io.txt
#   Syntropy NOIA whitepapers - whitepaper.io.txt
#   BitMart BMX whitepapers - whitepaper.io.txt
#   Terra Virtua Kolect TVK whitepapers - whitepaper.io.txt
#   Hyperion HYN whitepapers - whitepaper.io.txt
#   Cult DAO CULT whitepapers - whitepaper.io.txt
#   Akash Network AKT whitepapers - whitepaper.io.txt
#   Star Atlas ATLAS whitepapers - whitepaper.io.txt
#   Moss Coin MOC whitepapers - whitepaper.io.txt
#   Proton XPR whitepapers - whitepaper.io.txt
#   Refereum RFR whitepapers - whitepaper.io.txt
#   LTO Network LTO whitepapers - whitepaper.io.txt
#   HUNT HUNT whitepapers - whitepaper.io.txt
#   KardiaChain KAI whitepapers - whitepaper.io.txt
#   Bitcoin Diamond BCD whitepapers - whitepaper.io.txt
#   Elastos ELA whitepapers - whitepaper.io.txt
#   Era Swap ES whitepapers - whitepaper.io.txt
#   PIVX PIVX whitepapers - whitepaper.io.txt
#   DxChain DX whitepapers - whitepaper.io.txt
#   Presearch PRE whitepapers - whitepaper.io.txt
#   Ultiledger ULT whitepapers - whitepaper.io.txt
#   Groestlcoin GRS whitepapers - whitepaper.io.txt
#   Aeternity AE whitepapers - whitepaper.io.txt
#   Orion Protocol ORN whitepapers - whitepaper.io.txt
#   Bluzelle BLZ whitepapers - whitepaper.io.txt
#   CoinPoker CHP whitepapers - whitepaper.io.txt
#   Bitcicoin BITCI whitepapers - whitepaper.io.txt
#   District0x DNT whitepapers - whitepaper.io.txt
#   AirSwap AST whitepapers - whitepaper.io.txt
#   Tokenlon Network Token LON whitepapers - whitepaper.io.txt
#   Time New Bank TNB whitepapers - whitepaper.io.txt
#   Phantasma SOUL whitepapers - whitepaper.io.txt
#   Efforce WOZX whitepapers - whitepaper.io.txt
#   Selfkey KEY whitepapers - whitepaper.io.txt
#   MiL.k MLK whitepapers - whitepaper.io.txt
#   Elitium EUM whitepapers - whitepaper.io.txt
#   MANTRA DAO OM whitepapers - whitepaper.io.txt
#   Streamr DATAcoin DATA whitepapers - whitepaper.io.txt
#   LATOKEN LA whitepapers - whitepaper.io.txt
#   Beam BEAM whitepapers - whitepaper.io.txt
#   Cortex CTXC whitepapers - whitepaper.io.txt
#   AdEx ADX whitepapers - whitepaper.io.txt
#   Kin KIN whitepapers - whitepaper.io.txt
#   Litentry LIT whitepapers - whitepaper.io.txt
#   Waltonchain WTC whitepapers - whitepaper.io.txt
#   Ambrosus AMB whitepapers - whitepaper.io.txt
#   Unibright UBT whitepapers - whitepaper.io.txt
#   Mithril MITH whitepapers - whitepaper.io.txt
#   Akropolis AKRO whitepapers - whitepaper.io.txt
#   Saito SAITO whitepapers - whitepaper.io.txt
#   Gifto GTO whitepapers - whitepaper.io.txt
#   Viberate VIB whitepapers - whitepaper.io.txt
#   Haven Protocol XHV whitepapers - whitepaper.io.txt
#   Aion AION whitepapers - whitepaper.io.txt
#   Solve Care SOLVE whitepapers - whitepaper.io.txt
#   DeGate DG whitepapers - whitepaper.io.txt
#   NULS NULS whitepapers - whitepaper.io.txt
#   Dock DOCK whitepapers - whitepaper.io.txt
#   Hydra HYDRA whitepapers - whitepaper.io.txt
#   MAP Protocol MAP whitepapers - whitepaper.io.txt
#   Bytom BTM whitepapers - whitepaper.io.txt
#   pNetwork PNT whitepapers - whitepaper.io.txt
#   Kleros PNK whitepapers - whitepaper.io.txt
#   Nestree EGG whitepapers - whitepaper.io.txt
#   Apollo Currency APL whitepapers - whitepaper.io.txt
#   Measurable Data Token MDT whitepapers - whitepaper.io.txt
#   WaykiChain WICC whitepapers - whitepaper.io.txt
#   DigixDAO DGD whitepapers - whitepaper.io.txt
#   Fusion FSN whitepapers - whitepaper.io.txt
#   FOX TOKEN FOX whitepapers - whitepaper.io.txt
#   Cube AUTO whitepapers - whitepaper.io.txt
#   MimbleWimbleCoin MWC whitepapers - whitepaper.io.txt
#   Peercoin PPC whitepapers - whitepaper.io.txt
#   SONM SNM whitepapers - whitepaper.io.txt
#   All Sports SOC whitepapers - whitepaper.io.txt
#   DODO DODO whitepapers - whitepaper.io.txt
#   Metronome MET whitepapers - whitepaper.io.txt
#   Valobit VBIT whitepapers - whitepaper.io.txt
#   BTU Protocol BTU whitepapers - whitepaper.io.txt
#   apM Coin APM whitepapers - whitepaper.io.txt
#   ArcBlock ABT whitepapers - whitepaper.io.txt
#   VITE VITE whitepapers - whitepaper.io.txt
#   Yield App YLD whitepapers - whitepaper.io.txt
#   Hathor HTR whitepapers - whitepaper.io.txt
#   Bridge Oracle BRG whitepapers - whitepaper.io.txt
#   BOSAGORA BOA whitepapers - whitepaper.io.txt
#   DAD DAD whitepapers - whitepaper.io.txt
#   RedFOX Labs RFOX whitepapers - whitepaper.io.txt
#   Cajutel CAJ whitepapers - whitepaper.io.txt
#   Stratos STOS whitepapers - whitepaper.io.txt
#   Grid+ GRID whitepapers - whitepaper.io.txt
#   Obyte GBYTE whitepapers - whitepaper.io.txt
#   MILC Platform MLT whitepapers - whitepaper.io.txt
#   ZKSwap ZKS whitepapers - whitepaper.io.txt
#   PolySwarm NCT whitepapers - whitepaper.io.txt
#   1irstcoin FST whitepapers - whitepaper.io.txt
#   Somnium Space Cubes CUBE whitepapers - whitepaper.io.txt
#   Sensorium SENSO whitepapers - whitepaper.io.txt
#   Dacxi DACXI whitepapers - whitepaper.io.txt
#   Quantum Resistant Ledger QRL whitepapers - whitepaper.io.txt
#   Deeper Network DPR whitepapers - whitepaper.io.txt
#   Perlin PERL whitepapers - whitepaper.io.txt
#   Diamond DMD whitepapers - whitepaper.io.txt
#   Crypterium CRPT whitepapers - whitepaper.io.txt
#   ReddCoin RDD whitepapers - whitepaper.io.txt
#   Energi NRG whitepapers - whitepaper.io.txt
#   NuNet NTX whitepapers - whitepaper.io.txt
#   Cryptex Finance CTX whitepapers - whitepaper.io.txt
#   Callisto Network CLO whitepapers - whitepaper.io.txt
#   Switcheo SWTH whitepapers - whitepaper.io.txt
#   Newscrypto NWC whitepapers - whitepaper.io.txt
#   QASH (LIQUID) QASH whitepapers - whitepaper.io.txt
#   Adappter Token ADP whitepapers - whitepaper.io.txt
#   NewYork Exchange NYE whitepapers - whitepaper.io.txt
#   XeniosCoin XNC whitepapers - whitepaper.io.txt
#   Rupiah Token IDRT whitepapers - whitepaper.io.txt
#   ChainX PCX whitepapers - whitepaper.io.txt
#   DigitalBits XDB whitepapers - whitepaper.io.txt
#   Seele SEELE whitepapers - whitepaper.io.txt
#   Inflation Hedging Coin IHC whitepapers - whitepaper.io.txt
#   MASQ MASQ whitepapers - whitepaper.io.txt
#   Findora FRA whitepapers - whitepaper.io.txt
#   Insights Network INSTAR whitepapers - whitepaper.io.txt
#   Mobius MOBI whitepapers - whitepaper.io.txt
#   Observer OBSR whitepapers - whitepaper.io.txt
#   Edgeware EDG whitepapers - whitepaper.io.txt
#   TitanSwap TITAN whitepapers - whitepaper.io.txt
#   Scallop SCLP whitepapers - whitepaper.io.txt
#   ASTA ASTA whitepapers - whitepaper.io.txt
#   Swash SWASH whitepapers - whitepaper.io.txt
#   Retreeb TREEB whitepapers - whitepaper.io.txt
#   Dragonchain DRGN whitepapers - whitepaper.io.txt
#   Poseidon Network QQQ whitepapers - whitepaper.io.txt
#   AAX Token AAB whitepapers - whitepaper.io.txt
#   SMART VALOR VALOR whitepapers - whitepaper.io.txt
#   Hiblocks HIBS whitepapers - whitepaper.io.txt
#   Position Exchange POSI whitepapers - whitepaper.io.txt
#   SwftCoin SWFTC whitepapers - whitepaper.io.txt
#   OVR OVR whitepapers - whitepaper.io.txt
#   Cashaa CAS whitepapers - whitepaper.io.txt
#   Modum MOD whitepapers - whitepaper.io.txt
# Cluster 0:
#   SparkPoint SRK whitepapers - whitepaper.io.txt
#   Vidy VIDY whitepapers - whitepaper.io.txt
#   Breezecoin BRZE whitepapers - whitepaper.io.txt
#   Umbrella Network UMB whitepapers - whitepaper.io.txt
#   FlypMe FYP whitepapers - whitepaper.io.txt
#   Davinci Coin DAC whitepapers - whitepaper.io.txt
#   Delphy DPY whitepapers - whitepaper.io.txt
#   Autonio NIOX whitepapers - whitepaper.io.txt
#   Webflix Token WFX whitepapers - whitepaper.io.txt
#   BEMIL Coin BEM whitepapers - whitepaper.io.txt
#   Aditus ADI whitepapers - whitepaper.io.txt
#   Shield Protocol SHIELD whitepapers - whitepaper.io.txt
#   ImageCoin IMG whitepapers - whitepaper.io.txt
#   Idea Chain Coin ICH whitepapers - whitepaper.io.txt
#   BIZZCOIN BIZZ whitepapers - whitepaper.io.txt
#   Cometh MUST whitepapers - whitepaper.io.txt
#   Buzzshow GLDY whitepapers - whitepaper.io.txt
#   NftyPlay POLO whitepapers - whitepaper.io.txt
#   Ethera ETA whitepapers - whitepaper.io.txt
#   HALO network HO whitepapers - whitepaper.io.txt
#   Zeedex ZDEX whitepapers - whitepaper.io.txt
#   Everus EVR whitepapers - whitepaper.io.txt
#   HappyFans HAPPY whitepapers - whitepaper.io.txt
#   Dogira DOGIRA whitepapers - whitepaper.io.txt
#   Omni Real Estate Token ORT whitepapers - whitepaper.io.txt
#   Hachiko Inu INU whitepapers - whitepaper.io.txt
#   Kaiken Shiba KSHIB whitepapers - whitepaper.io.txt
#   WELD WELD whitepapers - whitepaper.io.txt
#   Revain R whitepapers - whitepaper.io.txt
#   StarLaunch STARS whitepapers - whitepaper.io.txt
#   UniLend Finance null whitepapers - whitepaper.io.txt
#   SquidGameToken SGT whitepapers - whitepaper.io.txt
#   AgaveCoin AGVC whitepapers - whitepaper.io.txt
#   Reborn royalty by royal AI $Crown whitepapers - whitepaper.io.txt
#   Aston ATX whitepapers - whitepaper.io.txt
#   MagnetGold MTG whitepapers - whitepaper.io.txt
#   ACA Token ACA whitepapers - whitepaper.io.txt
#   NEXT NET whitepapers - whitepaper.io.txt
#   Dogelana DGLN whitepapers - whitepaper.io.txt
#   Cryptonity XNY whitepapers - whitepaper.io.txt
#   MongolNFT Coin MNFT whitepapers - whitepaper.io.txt
#   Emocoin EMO whitepapers - whitepaper.io.txt
#   Hare Plus HARE PLUS whitepapers - whitepaper.io.txt
#   Belgian Malinois Token Belgian Malinois Token whitepapers - whitepaper.io.txt
#   Cryptonex CNX whitepapers - whitepaper.io.txt
#   TaaS TAAS whitepapers - whitepaper.io.txt
#   Ternio TERN whitepapers - whitepaper.io.txt
#   Spartan Inu Spartan Inu whitepapers - whitepaper.io.txt
#   Gale Network GALE whitepapers - whitepaper.io.txt
#   Good Driver Reward Token GDRT whitepapers - whitepaper.io.txt
#   INU INU whitepapers - whitepaper.io.txt
#   HotMoon Token HOTMOON whitepapers - whitepaper.io.txt
#   Idena IDNA whitepapers - whitepaper.io.txt
#   Kilo Shiba Inu KSHIB whitepapers - whitepaper.io.txt
#   Polygon MATIC whitepapers - whitepaper.io.txt
#   Kava.io KAVA whitepapers - whitepaper.io.txt
#   PRIZM PZM whitepapers - whitepaper.io.txt
#   UniLend UFT whitepapers - whitepaper.io.txt
# Cluster 1:
#   Docademic MTC whitepapers - whitepaper.io.txt
#   Dentacoin DCN whitepapers - whitepaper.io.txt
# Cluster 2:
#   Pawthereum PAWTH whitepapers - whitepaper.io.txt
#   Woodcoin LOG whitepapers - whitepaper.io.txt
# Cluster 3:
#   CoinAlpha ALP whitepapers - whitepaper.io.txt
#   Opal OPAL whitepapers - whitepaper.io.txt
# Cluster 4:
#   Compound USD Coin CUSDC whitepapers - whitepaper.io.txt
#   Compound 0x CZRX whitepapers - whitepaper.io.txt
#   Compound Dai CDAI whitepapers - whitepaper.io.txt
#   Compound Wrapped BTC CWBTC whitepapers - whitepaper.io.txt
#   Compound Basic Attention Token CBAT whitepapers - whitepaper.io.txt
#   Compound USDT CUSDT whitepapers - whitepaper.io.txt
# Cluster 5:
#   South African Tether xZAR whitepapers - whitepaper.io.txt
#   Coral Swap CORAL whitepapers - whitepaper.io.txt
# Cluster 6:
#   rhoUSDT RHOUSDT whitepapers - whitepaper.io.txt
#   Flurry Finance FLURRY whitepapers - whitepaper.io.txt
# Cluster 7:
#   stETH (Lido) STETH whitepapers - whitepaper.io.txt
#   Lido DAO LDO whitepapers - whitepaper.io.txt
# Cluster 8:
#   TerraClassicUSD USTC whitepapers - whitepaper.io.txt
#   Wrapped LUNA Classic WLUNC whitepapers - whitepaper.io.txt
#   TerraKRW KRT whitepapers - whitepaper.io.txt
# Cluster 9:
#   Pundi X (New) PUNDIX whitepapers - whitepaper.io.txt
#   Pundi X NPXS whitepapers - whitepaper.io.txt
# Cluster 10:
#   HOPPY HOP whitepapers - whitepaper.io.txt
#   Hop Protocol HOP whitepapers - whitepaper.io.txt
# Cluster 11:
#   ZUSD ZUSD whitepapers - whitepaper.io.txt
#   GYEN GYEN whitepapers - whitepaper.io.txt
# Cluster 12:
#   Sneakerbox NFT whitepapers - whitepaper.io.txt
#   Sneakerbox NFT null whitepapers - whitepaper.io.txt
# Cluster 13:
#   Loki LOKI whitepapers - whitepaper.io.txt
#   Oxen OXEN whitepapers - whitepaper.io.txt
# Cluster 14:
#   Block Ape Scissors BAS whitepapers - whitepaper.io.txt
#   DracooMaster BAS whitepapers - whitepaper.io.txt
# Cluster 15:
#   testprod1103202201 testprod1103202201 whitepapers - whitepaper.io.txt
#   testprod1103202203 testprod1103202203 whitepapers - whitepaper.io.txt
#   testprod2022110305 testprod2022110305 whitepapers - whitepaper.io.txt
#   asd null whitepapers - whitepaper.io.txt
#   teststagingdb001 teststagingdb001 whitepapers - whitepaper.io.txt
#   testprod20221027 testprod20221027 whitepapers - whitepaper.io.txt
#   teststagindb10272022 teststagindb10272022 whitepapers - whitepaper.io.txt
# Cluster 16:
#   MetaDoge METADOGE whitepapers - whitepaper.io.txt
#   b null whitepapers - whitepaper.io.txt
# Cluster 17:
#   Undead Finance UNDEAD whitepapers - whitepaper.io.txt
#   bitcon1 0x35131617a66472F9f0D384F41BbCCa7c999A149e whitepapers - whitepaper.io.txt
# Cluster 18:
#   POMCOIN POMC whitepapers - whitepaper.io.txt
#   bc1q3vu6xewzafwwh6nw0camfz7chu2fxfxxt29xax bc1q3vu6xewzafwwh6nw0camfz7chu2fxfxxt29xax whitepapers - whitepaper.io.txt
# Cluster 19:
#   HK Coin HKC whitepapers - whitepaper.io.txt
#   HongKetoCoin HKC whitepapers - whitepaper.io.txt
# Cluster 20:
#   Lotus null whitepapers - whitepaper.io.txt
#   Surfi Crypto SURFI whitepapers - whitepaper.io.txt
# Cluster 21:
#   Bloomify Static STATIC whitepapers - whitepaper.io.txt
#   Bloomify CHARGE whitepapers - whitepaper.io.txt
# Cluster 22:
#   Horde HOR whitepapers - whitepaper.io.txt
#   HoriemonCard HOR whitepapers - whitepaper.io.txt
# Cluster 23:
#   SwapDEX Network null whitepapers - whitepaper.io.txt
#   Soccer Dudes null whitepapers - whitepaper.io.txt
#   Furries Exclusive Polygon (ERC-721) whitepapers - whitepaper.io.txt
# Cluster 24:
#   KEYS KEYS whitepapers - whitepaper.io.txt
#   Sega Crown eth whitepapers - whitepaper.io.txt
# Cluster 25:
#   WX Token WX whitepapers - whitepaper.io.txt
#   TikTok Dollar TTD whitepapers - whitepaper.io.txt
# Cluster 26:
#   BTRIPS BTR whitepapers - whitepaper.io.txt
#   Bela BELA whitepapers - whitepaper.io.txt
# Cluster 27:
#   BAB_L TOKEN BABIL whitepapers - whitepaper.io.txt
#   Teddy Doge Teddy V2 whitepapers - whitepaper.io.txt
# Cluster 28:
#   Fei Protocol FEI whitepapers - whitepaper.io.txt
#   Tribe TRIBE whitepapers - whitepaper.io.txt
# Cluster 29:
#   USDJ USDJ whitepapers - whitepaper.io.txt
#   JUST JST whitepapers - whitepaper.io.txt
# Cluster 30:
#   Steemit STEEM whitepapers - whitepaper.io.txt
#   Steem Dollars SBD whitepapers - whitepaper.io.txt
# Cluster 31:
#   Vai VAI whitepapers - whitepaper.io.txt
#   Venus XVS whitepapers - whitepaper.io.txt
# DBSCAN 결과가 CSV 파일로 저장되었습니다.
