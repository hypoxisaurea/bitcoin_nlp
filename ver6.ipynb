# %% [markdown]
# Doc2Vec, DBSCAN 사용 <br/>
# GridSearch를 사용한 파라미터 최적화 <br/>
# nltk 영어 불용어, 빈도수를 이용한 불용어 250개를 추출하여 사용 <br/>
# ver1과 비교하여 클러스터 갯수 유지, 노이즈 포인트 감소 실루엣 스코어 미세하게 상승 <br/><br/>
#
# Best DBSCAN params: eps=2.0, min_samples=4 with Silhouette Score=-0.08230538796258437<br/>
# Number of clusters: 4<br/>
# Number of noise points: 1084

# %%
import os
import glob
import string
from tqdm import tqdm
from collections import Counter
from gensim.models.doc2vec import TaggedDocument, Doc2Vec
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
# nltk 데이터 다운로드 (최초 실행 시 필요)
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# NLTK 초기화
lemmatizer = WordNetLemmatizer()

# %%
# txt 파일 경로 설정 (Google Drive의 경로로 변경)
path = '/content/drive/MyDrive/bitcoin_nlp'
output_path = '/content/drive/MyDrive/bitcoin_nlp/preprocessed'

# %%
# 구두점 제거 함수
def remove_punctuation(text):
    return text.translate(str.maketrans('', '', string.punctuation))

# %%
# 불용어 제거 함수
def remove_stopwords(text, stopwords):
    words = text.split()
    words = [word for word in words if word.lower() not in stopwords]
    return ' '.join(words)

# %%
# 표제어 추출 함수
def lemmatize_words(text):
    words = text.split()
    lemmatized_words = [lemmatizer.lemmatize(word, pos='v') for word in words]
    return ' '.join(lemmatized_words)

# %%
# 각 문서에서 빈도가 가장 높은 단어 100개 추출
def get_top_n_words(documents, n=100):
    top_words = []
    for filename, content in documents:
        words = content.split()
        word_counts = Counter(words)
        top_n = [word for word, count in word_counts.most_common(n)]
        top_words.append((filename, top_n))
    return top_words

# %%
# 최빈 단어 기반 문서 벡터 생성
def create_document_vectors(top_words, all_words_set):
    vectors = []
    for filename, words in top_words:
        vector = np.zeros(len(all_words_set))
        for word in words:
            if word in all_words_set:
                vector[list(all_words_set).index(word)] = 1
        vectors.append((filename, vector))
    return vectors

# %%
# 텍스트 파일 읽기 및 전처리 (구두점 제거, 불용어 제거, 표제어 추출)
def read_and_preprocess_files(path, stopwords_list):
    files = glob.glob(os.path.join(path, '*.txt'))
    documents = []
    for file in tqdm(files, desc="Reading and preprocessing files"):
        with open(file, 'r', encoding='utf-8') as f:
            content = f.read()
            content = remove_punctuation(content)  # 구두점 제거
            content = remove_stopwords(content, stopwords_list)  # 불용어 제거
            content = lemmatize_words(content)  # 표제어 추출
            documents.append((os.path.basename(file), content))
    return documents

# %%
# 전처리된 파일 저장
def save_preprocessed_files(documents, output_path):
    if not os.path.exists(output_path):
        os.makedirs(output_path)

    for filename, content in documents:
        # 기존 파일 이름 뒤에 '_preprocessed' 추가
        preprocessed_filename = os.path.splitext(filename)[0] + '_preprocessed.txt'
        with open(os.path.join(output_path, preprocessed_filename), 'w', encoding='utf-8') as f:
            f.write(content)

# %%
# 불용어 리스트 생성 (빈도 기반)
def create_stopwords(documents, top_n=250):
    all_words = []
    for doc in documents:
        all_words.extend(doc[1].split())
    word_counts = Counter(all_words)
    stopwords_list = [word for word, count in word_counts.most_common(top_n)]
    return stopwords_list

# %%
# 문서 태그 및 형태소 분석
def tag_documents(documents):
    tagged_documents = [TaggedDocument(doc.split(), [i]) for i, (name, doc) in enumerate(tqdm(documents, desc="Tagging documents"))]
    return tagged_documents

# %%
# Doc2Vec 모델 파라미터 최적화
def optimize_doc2vec(tagged_corpus_list, documents):
    vector_size = [20, 25]
    windows = [3, 5]
    alphas = [0.03, 0.05]
    min_alphas = [0.0001, 0.0002, 0.0003]

    best_doc2vec_params = None
    best_doc2vec_score = -1

    for vector_size in vector_size:
      for window in windows:
          for alpha in alphas:
              for min_alpha in min_alphas:
                  print(f"Training Doc2Vec with vector_size={vector_size}, window={window}, alpha={alpha}, min_alpha={min_alpha}")
                  model = Doc2Vec(vector_size=vector_size, window=window, alpha=alpha, min_alpha=min_alpha, workers=8)
                  model.build_vocab(tagged_corpus_list)
                  model.train(tagged_corpus_list, total_examples=model.corpus_count, epochs=30)

                  # 벡터 추출
                  vectors = [model.dv[i] for i in range(len(documents))]
                  X = np.array(vectors)

                  # 벡터 스케일링
                  scaler = StandardScaler()
                  X_scaled = scaler.fit_transform(X)

                  # DBSCAN 클러스터링 및 평가
                  dbscan = DBSCAN(eps=2.0, min_samples=8, metric='euclidean')
                  clusters = dbscan.fit_predict(X_scaled)

                  if len(set(clusters)) > 1:
                      score = silhouette_score(X_scaled, clusters)
                      print(f"Silhouette Score: {score:.2f}")
                      if score > best_doc2vec_score:
                          best_doc2vec_score = score
                          best_doc2vec_params = (vector_size, window, alpha, min_alpha)

    if best_doc2vec_params:
        print(f"Best Doc2Vec params: vector_size={best_doc2vec_params[0]}, window={best_doc2vec_params[1]}, alpha={best_doc2vec_params[2]}, min_alpha={best_doc2vec_params[3]} with Silhouette Score={best_doc2vec_score:.2f}")
    else:
        print("No optimal parameters found. Silhouette scores were not positive for any parameter combination.")

    return best_doc2vec_params

# %%
# 문서 읽기
documents = read_and_preprocess_files(path, [])
# Out:
# Reading and preprocessing files: 100%|██████████| 1373/1373 [00:43<00:00, 31.26it/s]

# %%
# 기본 영어 불용어 리스트 가져오기
default_stopwords = set(stopwords.words('english'))

# %%
# 불용어 리스트 생성
custom_stopwords = create_stopwords(documents)
custom_stopwords
# Out:
# ['the',
#  'be',
#  'of',
#  'and',
#  'to',
#  'a',
#  'in',
#  'for',
#  '\u200b',
#  'that',
#  'will',
#  'The',
#  'on',
#  'as',
#  'or',
#  'with',
#  'by',
#  'have',
#  'can',
#  'use',
#  'an',
#  'from',
#  'this',
#  'not',
#  '\u200b\u200b',
#  'it',
#  'their',
#  'any',
#  'blockchain',
#  'which',
#  'data',
#  'network',
#  'at',
#  'all',
#  'market',
#  'other',
#  'This',
#  'service',
#  'contract',
#  'tokens',
#  '•',
#  'In',
#  'provide',
#  'users',
#  'we',
#  'platform',
#  '1',
#  'more',
#  'token',
#  'such',
#  'its',
#  'time',
#  'block',
#  'make',
#  'system',
#  'transaction',
#  'A',
#  'also',
#  'value',
#  'new',
#  'do',
#  'exchange',
#  '2',
#  'may',
#  'our',
#  'they',
#  'create',
#  'transactions',
#  'Token',
#  'include',
#  'information',
#  'only',
#  'one',
#  'process',
#  'need',
#  'allow',
#  'user',
#  'into',
#  'smart',
#  'base',
#  'each',
#  'through',
#  'trade',
#  'project',
#  'but',
#  'fee',
#  'technology',
#  'We',
#  '3',
#  'you',
#  'reward',
#  'price',
#  'number',
#  'these',
#  'chain',
#  'no',
#  '●',
#  'development',
#  'It',
#  'nod',
#  'if',
#  'account',
#  'order',
#  'Ethereum',
#  'than',
#  'require',
#  'key',
#  'fund',
#  'assets',
#  'offer',
#  'work',
#  'there',
#  'amount',
#  'ecosystem',
#  'decentralize',
#  'digital',
#  'company',
#  'protocol',
#  'build',
#  'community',
#  'where',
#  '5',
#  'business',
#  'game',
#  'support',
#  'financial',
#  'between',
#  '4',
#  'set',
#  '10',
#  'receive',
#  'who',
#  'cryptocurrency',
#  'would',
#  'follow',
#  'access',
#  'coin',
#  'team',
#  'node',
#  'share',
#  'change',
#  'when',
#  'risk',
#  'increase',
#  'them',
#  'security',
#  'stake',
#  'first',
#  'public',
#  'cost',
#  'own',
#  'Blockchain',
#  'For',
#  'over',
#  'model',
#  'purchase',
#  'payment',
#  'As',
#  'most',
#  'vote',
#  'address',
#  'result',
#  'distribute',
#  'take',
#  'design',
#  'different',
#  'content',
#  'Bitcoin',
#  'so',
#  'issue',
#  'case',
#  'without',
#  'give',
#  'up',
#  'pay',
#  'asset',
#  'develop',
#  'consensus',
#  'future',
#  'experience',
#  'many',
#  'If',
#  'store',
#  'same',
#  'Platform',
#  'become',
#  'able',
#  'your',
#  'mine',
#  'function',
#  'Tokens',
#  'way',
#  'world',
#  'then',
#  'within',
#  'hold',
#  'Network',
#  'should',
#  'party',
#  'out',
#  'form',
#  'wallet',
#  'transfer',
#  'some',
#  'part',
#  'two',
#  'exist',
#  'must',
#  'ensure',
#  'well',
#  '–',
#  'like',
#  'currency',
#  'could',
#  'both',
#  '6',
#  'enable',
#  'available',
#  'To',
#  'applications',
#  'mean',
#  'get',
#  'crypto',
#  'limit',
#  'feature',
#  'right',
#  'industry',
#  'example',
#  'generate',
#  'control',
#  'send',
#  'state',
#  'investment',
#  'every',
#  'supply',
#  'private',
#  'about',
#  'power',
#  'hash',
#  'All',
#  'application',
#  'sell',
#  'Smart',
#  'liquidity',
#  'high',
#  'run',
#  'storage',
#  'total',
#  'current',
#  'while']

# %%
# 기본 불용어 리스트와 사용자 정의 불용어 리스트 병합
combined_stopwords = default_stopwords.union(custom_stopwords)

# %%
# 문서 다시 읽기 및 전처리
documents = read_and_preprocess_files(path, combined_stopwords)
# Out:
# Reading and preprocessing files: 100%|██████████| 1373/1373 [00:22<00:00, 60.25it/s]

# %%
# 전처리된 파일 저장
save_preprocessed_files(documents, output_path)

# %%
# 태그된 문서 리스트 생성
tagged_corpus_list = tag_documents(documents)
# Out:
# Tagging documents: 100%|██████████| 1373/1373 [00:00<00:00, 3388.14it/s]

# %%
best_params = optimize_doc2vec(tagged_corpus_list, documents)
# Out:
# Training Doc2Vec with vector_size=20, window=3, alpha=0.03, min_alpha=0.0001
# Silhouette Score: -0.16
# Training Doc2Vec with vector_size=20, window=3, alpha=0.03, min_alpha=0.0002
# Silhouette Score: -0.16
# Training Doc2Vec with vector_size=20, window=3, alpha=0.03, min_alpha=0.0003
# Silhouette Score: -0.19
# Training Doc2Vec with vector_size=20, window=3, alpha=0.05, min_alpha=0.0001
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=20, window=3, alpha=0.05, min_alpha=0.0002
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=20, window=3, alpha=0.05, min_alpha=0.0003
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=20, window=5, alpha=0.03, min_alpha=0.0001
# Silhouette Score: -0.15
# Training Doc2Vec with vector_size=20, window=5, alpha=0.03, min_alpha=0.0002
# Silhouette Score: -0.15
# Training Doc2Vec with vector_size=20, window=5, alpha=0.03, min_alpha=0.0003
# Silhouette Score: -0.15
# Training Doc2Vec with vector_size=20, window=5, alpha=0.05, min_alpha=0.0001
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=20, window=5, alpha=0.05, min_alpha=0.0002
# Silhouette Score: -0.20
# Training Doc2Vec with vector_size=20, window=5, alpha=0.05, min_alpha=0.0003
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=3, alpha=0.03, min_alpha=0.0001
# Silhouette Score: -0.16
# Training Doc2Vec with vector_size=25, window=3, alpha=0.03, min_alpha=0.0002
# Silhouette Score: -0.16
# Training Doc2Vec with vector_size=25, window=3, alpha=0.03, min_alpha=0.0003
# Silhouette Score: -0.16
# Training Doc2Vec with vector_size=25, window=3, alpha=0.05, min_alpha=0.0001
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=3, alpha=0.05, min_alpha=0.0002
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=3, alpha=0.05, min_alpha=0.0003
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=5, alpha=0.03, min_alpha=0.0001
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=5, alpha=0.03, min_alpha=0.0002
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=5, alpha=0.03, min_alpha=0.0003
# Silhouette Score: -0.17
# Training Doc2Vec with vector_size=25, window=5, alpha=0.05, min_alpha=0.0001
# Silhouette Score: -0.18
# Training Doc2Vec with vector_size=25, window=5, alpha=0.05, min_alpha=0.0002
# Silhouette Score: -0.18
# Training Doc2Vec with vector_size=25, window=5, alpha=0.05, min_alpha=0.0003
# Silhouette Score: -0.17
# Best Doc2Vec params: vector_size=20, window=5, alpha=0.03, min_alpha=0.0002 with Silhouette Score=-0.15

# %%
# 최적의 Doc2Vec 파라미터로 모델 학습
vector_size, window, alpha, min_alpha = best_params
model = Doc2Vec(vector_size=vector_size, window=window, alpha=alpha, min_alpha=min_alpha, workers=8)
model.build_vocab(tagged_corpus_list)
model.train(tagged_corpus_list, total_examples=model.corpus_count, epochs=10)

# %%
# 최적화된 모델로 벡터 추출 및 저장
vectors = [model.dv[i] for i in range(len(documents))]
output_dir = '/content/drive/MyDrive/bitcoin_nlp/vectors'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for i, vector in enumerate(vectors):
    vector_path = os.path.join(output_dir, f'vector_{i}.txt')
    np.savetxt(vector_path, vector)

# %%
# 벡터 파일 읽기
def load_vectors(vector_dir):
    vector_files = sorted(glob.glob(os.path.join(vector_dir, 'vector_*.txt')))
    vectors = []
    for file in tqdm(vector_files, desc="Loading vectors"):
        vector = np.loadtxt(file)
        vectors.append(vector)
    return vectors, vector_files

# %%
vectors, vector_files = load_vectors(output_dir)

# 벡터를 numpy 배열로 변환
X = np.array(vectors)

# 데이터를 스케일링
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# Loading vectors: 100%|██████████| 1373/1373 [00:13<00:00, 104.43it/s]

# %%
# Grid Search를 사용한 DBSCAN 파라미터 최적화
eps_values = np.arange(0.1, 2.1, 0.1)
min_samples_values = list(range(2, 31, 2))
best_dbscan_score = -1
best_dbscan_params = None

# %%
for eps in eps_values:
    for min_samples in min_samples_values:
        print(f"Running DBSCAN with eps={eps}, min_samples={min_samples}")
        dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean')
        clusters = dbscan.fit_predict(X_scaled)

        # 클러스터링 평가 (Silhouette Score 사용)
        if len(set(clusters)) > 1:
            score = silhouette_score(X_scaled, clusters)
            print(f"Silhouette Score: {score}")
            if score > best_dbscan_score:
                best_dbscan_score = score
                best_dbscan_params = (eps, min_samples)
# Out:
# Running DBSCAN with eps=0.1, min_samples=2
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=4
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=6
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=8
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=10
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=12
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=14
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=16
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=18
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=20
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=22
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=24
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=26
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=28
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.1, min_samples=30
# Silhouette Score: -0.18973010523984832
# Running DBSCAN with eps=0.2, min_samples=2
# Silhouette Score: -0.23786940152361338
# Running DBSCAN with eps=0.2, min_samples=4
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=6
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=8
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=10
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=12
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=14
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=16
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=18
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=20
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=22
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=24
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=26
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=28
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.2, min_samples=30
# Silhouette Score: -0.18764114360414919
# Running DBSCAN with eps=0.30000000000000004, min_samples=2
# Silhouette Score: -0.22838472817432023
# Running DBSCAN with eps=0.30000000000000004, min_samples=4
# Silhouette Score: -0.2108175031101154
# Running DBSCAN with eps=0.30000000000000004, min_samples=6
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=8
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=10
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=12
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=14
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=16
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=18
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=20
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=22
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=24
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=26
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=28
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.30000000000000004, min_samples=30
# Silhouette Score: -0.18471396196065523
# Running DBSCAN with eps=0.4, min_samples=2
# Silhouette Score: -0.2460787526903713
# Running DBSCAN with eps=0.4, min_samples=4
# Silhouette Score: -0.20898955284241202
# Running DBSCAN with eps=0.4, min_samples=6
# Silhouette Score: -0.20898955284241202
# Running DBSCAN with eps=0.4, min_samples=8
# Silhouette Score: -0.18154403869201097
# Running DBSCAN with eps=0.4, min_samples=10
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=12
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=14
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=16
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=18
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=20
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=22
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=24
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=26
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=28
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.4, min_samples=30
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=2
# Silhouette Score: -0.2565791564766818
# Running DBSCAN with eps=0.5, min_samples=4
# Silhouette Score: -0.20859642509158702
# Running DBSCAN with eps=0.5, min_samples=6
# Silhouette Score: -0.20859642509158702
# Running DBSCAN with eps=0.5, min_samples=8
# Silhouette Score: -0.18022032366208693
# Running DBSCAN with eps=0.5, min_samples=10
# Silhouette Score: -0.18096756806572065
# Running DBSCAN with eps=0.5, min_samples=12
# Silhouette Score: -0.18096756806572065
# Running DBSCAN with eps=0.5, min_samples=14
# Silhouette Score: -0.18096756806572065
# Running DBSCAN with eps=0.5, min_samples=16
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=18
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=20
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=22
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=24
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=26
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=28
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.5, min_samples=30
# Silhouette Score: -0.18186933231710165
# Running DBSCAN with eps=0.6, min_samples=2
# Silhouette Score: -0.27797500415859494
# Running DBSCAN with eps=0.6, min_samples=4
# Silhouette Score: -0.2160120642633528
# Running DBSCAN with eps=0.6, min_samples=6
# Silhouette Score: -0.2088635584202399
# Running DBSCAN with eps=0.6, min_samples=8
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=10
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=12
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=14
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=16
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=18
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=20
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=22
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=24
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=26
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=28
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.6, min_samples=30
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=2
# Silhouette Score: -0.2628872469933451
# Running DBSCAN with eps=0.7000000000000001, min_samples=4
# Silhouette Score: -0.18028139874945695
# Running DBSCAN with eps=0.7000000000000001, min_samples=6
# Silhouette Score: -0.1741091725537724
# Running DBSCAN with eps=0.7000000000000001, min_samples=8
# Silhouette Score: -0.1741091725537724
# Running DBSCAN with eps=0.7000000000000001, min_samples=10
# Silhouette Score: -0.17630286461760877
# Running DBSCAN with eps=0.7000000000000001, min_samples=12
# Silhouette Score: -0.17630286461760877
# Running DBSCAN with eps=0.7000000000000001, min_samples=14
# Silhouette Score: -0.17624589978944918
# Running DBSCAN with eps=0.7000000000000001, min_samples=16
# Silhouette Score: -0.1766545459247939
# Running DBSCAN with eps=0.7000000000000001, min_samples=18
# Silhouette Score: -0.1766545459247939
# Running DBSCAN with eps=0.7000000000000001, min_samples=20
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=22
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=24
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=26
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=28
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.7000000000000001, min_samples=30
# Silhouette Score: -0.1793435400749635
# Running DBSCAN with eps=0.8, min_samples=2
# Silhouette Score: -0.25978352807566646
# Running DBSCAN with eps=0.8, min_samples=4
# Silhouette Score: -0.17743285551524984
# Running DBSCAN with eps=0.8, min_samples=6
# Silhouette Score: -0.17233982740062273
# Running DBSCAN with eps=0.8, min_samples=8
# Silhouette Score: -0.1727251677102663
# Running DBSCAN with eps=0.8, min_samples=10
# Silhouette Score: -0.1727251677102663
# Running DBSCAN with eps=0.8, min_samples=12
# Silhouette Score: -0.1727251677102663
# Running DBSCAN with eps=0.8, min_samples=14
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=16
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=18
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=20
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=22
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=24
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=26
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=28
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.8, min_samples=30
# Silhouette Score: -0.17310863647855063
# Running DBSCAN with eps=0.9, min_samples=2
# Silhouette Score: -0.2558211389842193
# Running DBSCAN with eps=0.9, min_samples=4
# Silhouette Score: -0.1771612259029953
# Running DBSCAN with eps=0.9, min_samples=6
# Silhouette Score: -0.1771612259029953
# Running DBSCAN with eps=0.9, min_samples=8
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=10
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=12
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=14
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=16
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=18
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=20
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=22
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=24
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=26
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=28
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=0.9, min_samples=30
# Silhouette Score: -0.17210101076787018
# Running DBSCAN with eps=1.0, min_samples=2
# Silhouette Score: -0.26042854843642915
# Running DBSCAN with eps=1.0, min_samples=4
# Silhouette Score: -0.2098017531884154
# Running DBSCAN with eps=1.0, min_samples=6
# Silhouette Score: -0.1734924889624584
# Running DBSCAN with eps=1.0, min_samples=8
# Silhouette Score: -0.16891967161064866
# Running DBSCAN with eps=1.0, min_samples=10
# Silhouette Score: -0.16891967161064866
# Running DBSCAN with eps=1.0, min_samples=12
# Silhouette Score: -0.16891967161064866
# Running DBSCAN with eps=1.0, min_samples=14
# Silhouette Score: -0.16891967161064866
# Running DBSCAN with eps=1.0, min_samples=16
# Silhouette Score: -0.16975305004133145
# Running DBSCAN with eps=1.0, min_samples=18
# Silhouette Score: -0.16975305004133145
# Running DBSCAN with eps=1.0, min_samples=20
# Silhouette Score: -0.17020870026362714
# Running DBSCAN with eps=1.0, min_samples=22
# Silhouette Score: -0.17100931446200976
# Running DBSCAN with eps=1.0, min_samples=24
# Silhouette Score: -0.17100931446200976
# Running DBSCAN with eps=1.0, min_samples=26
# Silhouette Score: -0.17100931446200976
# Running DBSCAN with eps=1.0, min_samples=28
# Silhouette Score: -0.17100931446200976
# Running DBSCAN with eps=1.0, min_samples=30
# Silhouette Score: -0.17100931446200976
# Running DBSCAN with eps=1.1, min_samples=2
# Silhouette Score: -0.2532625644504321
# Running DBSCAN with eps=1.1, min_samples=4
# Silhouette Score: -0.2118044354626472
# Running DBSCAN with eps=1.1, min_samples=6
# Silhouette Score: -0.16902569110482285
# Running DBSCAN with eps=1.1, min_samples=8
# Silhouette Score: -0.1657610129136162
# Running DBSCAN with eps=1.1, min_samples=10
# Silhouette Score: -0.1657610129136162
# Running DBSCAN with eps=1.1, min_samples=12
# Silhouette Score: -0.16816052223344935
# Running DBSCAN with eps=1.1, min_samples=14
# Silhouette Score: -0.16816052223344935
# Running DBSCAN with eps=1.1, min_samples=16
# Silhouette Score: -0.16816052223344935
# Running DBSCAN with eps=1.1, min_samples=18
# Silhouette Score: -0.16816052223344935
# Running DBSCAN with eps=1.1, min_samples=20
# Silhouette Score: -0.16816052223344935
# Running DBSCAN with eps=1.1, min_samples=22
# Silhouette Score: -0.16849022726710133
# Running DBSCAN with eps=1.1, min_samples=24
# Silhouette Score: -0.16849022726710133
# Running DBSCAN with eps=1.1, min_samples=26
# Silhouette Score: -0.16858501905277834
# Running DBSCAN with eps=1.1, min_samples=28
# Silhouette Score: -0.16858501905277834
# Running DBSCAN with eps=1.1, min_samples=30
# Silhouette Score: -0.16858501905277834
# Running DBSCAN with eps=1.2000000000000002, min_samples=2
# Silhouette Score: -0.24186997190842296
# Running DBSCAN with eps=1.2000000000000002, min_samples=4
# Silhouette Score: -0.1587251715914512
# Running DBSCAN with eps=1.2000000000000002, min_samples=6
# Silhouette Score: -0.16258102299583063
# Running DBSCAN with eps=1.2000000000000002, min_samples=8
# Silhouette Score: -0.16107184369277935
# Running DBSCAN with eps=1.2000000000000002, min_samples=10
# Silhouette Score: -0.16208738756372615
# Running DBSCAN with eps=1.2000000000000002, min_samples=12
# Silhouette Score: -0.16208738756372615
# Running DBSCAN with eps=1.2000000000000002, min_samples=14
# Silhouette Score: -0.16262476520546912
# Running DBSCAN with eps=1.2000000000000002, min_samples=16
# Silhouette Score: -0.1630146739498006
# Running DBSCAN with eps=1.2000000000000002, min_samples=18
# Silhouette Score: -0.16407361066108628
# Running DBSCAN with eps=1.2000000000000002, min_samples=20
# Silhouette Score: -0.16407361066108628
# Running DBSCAN with eps=1.2000000000000002, min_samples=22
# Silhouette Score: -0.16495884281354117
# Running DBSCAN with eps=1.2000000000000002, min_samples=24
# Silhouette Score: -0.16495884281354117
# Running DBSCAN with eps=1.2000000000000002, min_samples=26
# Silhouette Score: -0.16495884281354117
# Running DBSCAN with eps=1.2000000000000002, min_samples=28
# Silhouette Score: -0.16495884281354117
# Running DBSCAN with eps=1.2000000000000002, min_samples=30
# Silhouette Score: -0.16495884281354117
# Running DBSCAN with eps=1.3000000000000003, min_samples=2
# Silhouette Score: -0.23862145945065302
# Running DBSCAN with eps=1.3000000000000003, min_samples=4
# Silhouette Score: -0.15191533854193667
# Running DBSCAN with eps=1.3000000000000003, min_samples=6
# Silhouette Score: -0.1559420991353002
# Running DBSCAN with eps=1.3000000000000003, min_samples=8
# Silhouette Score: -0.15516796701975158
# Running DBSCAN with eps=1.3000000000000003, min_samples=10
# Silhouette Score: -0.15516796701975158
# Running DBSCAN with eps=1.3000000000000003, min_samples=12
# Silhouette Score: -0.15582867397937042
# Running DBSCAN with eps=1.3000000000000003, min_samples=14
# Silhouette Score: -0.15582867397937042
# Running DBSCAN with eps=1.3000000000000003, min_samples=16
# Silhouette Score: -0.1567061839192721
# Running DBSCAN with eps=1.3000000000000003, min_samples=18
# Silhouette Score: -0.15716632896492533
# Running DBSCAN with eps=1.3000000000000003, min_samples=20
# Silhouette Score: -0.15716632896492533
# Running DBSCAN with eps=1.3000000000000003, min_samples=22
# Silhouette Score: -0.15716632896492533
# Running DBSCAN with eps=1.3000000000000003, min_samples=24
# Silhouette Score: -0.15716632896492533
# Running DBSCAN with eps=1.3000000000000003, min_samples=26
# Silhouette Score: -0.15716632896492533
# Running DBSCAN with eps=1.3000000000000003, min_samples=28
# Silhouette Score: -0.16153416312807367
# Running DBSCAN with eps=1.3000000000000003, min_samples=30
# Silhouette Score: -0.16153416312807367
# Running DBSCAN with eps=1.4000000000000001, min_samples=2
# Silhouette Score: -0.22914698809898643
# Running DBSCAN with eps=1.4000000000000001, min_samples=4
# Silhouette Score: -0.1458333005213806
# Running DBSCAN with eps=1.4000000000000001, min_samples=6
# Silhouette Score: -0.14805485142525798
# Running DBSCAN with eps=1.4000000000000001, min_samples=8
# Silhouette Score: -0.1456417086657078
# Running DBSCAN with eps=1.4000000000000001, min_samples=10
# Silhouette Score: -0.1468635302688071
# Running DBSCAN with eps=1.4000000000000001, min_samples=12
# Silhouette Score: -0.14745039442765673
# Running DBSCAN with eps=1.4000000000000001, min_samples=14
# Silhouette Score: -0.14745039442765673
# Running DBSCAN with eps=1.4000000000000001, min_samples=16
# Silhouette Score: -0.1488012078258169
# Running DBSCAN with eps=1.4000000000000001, min_samples=18
# Silhouette Score: -0.1488012078258169
# Running DBSCAN with eps=1.4000000000000001, min_samples=20
# Silhouette Score: -0.1488012078258169
# Running DBSCAN with eps=1.4000000000000001, min_samples=22
# Silhouette Score: -0.1488012078258169
# Running DBSCAN with eps=1.4000000000000001, min_samples=24
# Silhouette Score: -0.14929280784844018
# Running DBSCAN with eps=1.4000000000000001, min_samples=26
# Silhouette Score: -0.14929280784844018
# Running DBSCAN with eps=1.4000000000000001, min_samples=28
# Silhouette Score: -0.15244838847323922
# Running DBSCAN with eps=1.4000000000000001, min_samples=30
# Silhouette Score: -0.15244838847323922
# Running DBSCAN with eps=1.5000000000000002, min_samples=2
# Silhouette Score: -0.23099204478582872
# Running DBSCAN with eps=1.5000000000000002, min_samples=4
# Silhouette Score: -0.13834355570789064
# Running DBSCAN with eps=1.5000000000000002, min_samples=6
# Silhouette Score: -0.1421216162788555
# Running DBSCAN with eps=1.5000000000000002, min_samples=8
# Silhouette Score: -0.13900276125641095
# Running DBSCAN with eps=1.5000000000000002, min_samples=10
# Silhouette Score: -0.140288136443878
# Running DBSCAN with eps=1.5000000000000002, min_samples=12
# Silhouette Score: -0.140288136443878
# Running DBSCAN with eps=1.5000000000000002, min_samples=14
# Silhouette Score: -0.1419320314616243
# Running DBSCAN with eps=1.5000000000000002, min_samples=16
# Silhouette Score: -0.14327920163788582
# Running DBSCAN with eps=1.5000000000000002, min_samples=18
# Silhouette Score: -0.14378510199319883
# Running DBSCAN with eps=1.5000000000000002, min_samples=20
# Silhouette Score: -0.14480360223080305
# Running DBSCAN with eps=1.5000000000000002, min_samples=22
# Silhouette Score: -0.14480360223080305
# Running DBSCAN with eps=1.5000000000000002, min_samples=24
# Silhouette Score: -0.14588165392222088
# Running DBSCAN with eps=1.5000000000000002, min_samples=26
# Silhouette Score: -0.14629641256188858
# Running DBSCAN with eps=1.5000000000000002, min_samples=28
# Silhouette Score: -0.14629641256188858
# Running DBSCAN with eps=1.5000000000000002, min_samples=30
# Silhouette Score: -0.14629641256188858
# Running DBSCAN with eps=1.6, min_samples=2
# Silhouette Score: -0.2235692220700448
# Running DBSCAN with eps=1.6, min_samples=4
# Silhouette Score: -0.17414933216637482
# Running DBSCAN with eps=1.6, min_samples=6
# Silhouette Score: -0.13467566128670727
# Running DBSCAN with eps=1.6, min_samples=8
# Silhouette Score: -0.1330238538572392
# Running DBSCAN with eps=1.6, min_samples=10
# Silhouette Score: -0.1330238538572392
# Running DBSCAN with eps=1.6, min_samples=12
# Silhouette Score: -0.1330238538572392
# Running DBSCAN with eps=1.6, min_samples=14
# Silhouette Score: -0.13428966631834902
# Running DBSCAN with eps=1.6, min_samples=16
# Silhouette Score: -0.13428966631834902
# Running DBSCAN with eps=1.6, min_samples=18
# Silhouette Score: -0.13600078382334707
# Running DBSCAN with eps=1.6, min_samples=20
# Silhouette Score: -0.13600078382334707
# Running DBSCAN with eps=1.6, min_samples=22
# Silhouette Score: -0.13600078382334707
# Running DBSCAN with eps=1.6, min_samples=24
# Silhouette Score: -0.13812502692299547
# Running DBSCAN with eps=1.6, min_samples=26
# Silhouette Score: -0.13812502692299547
# Running DBSCAN with eps=1.6, min_samples=28
# Silhouette Score: -0.13812502692299547
# Running DBSCAN with eps=1.6, min_samples=30
# Silhouette Score: -0.1397191641082157
# Running DBSCAN with eps=1.7000000000000002, min_samples=2
# Silhouette Score: -0.20575737017369114
# Running DBSCAN with eps=1.7000000000000002, min_samples=4
# Silhouette Score: -0.1762401398415239
# Running DBSCAN with eps=1.7000000000000002, min_samples=6
# Silhouette Score: -0.12601821724614554
# Running DBSCAN with eps=1.7000000000000002, min_samples=8
# Silhouette Score: -0.12426034084756057
# Running DBSCAN with eps=1.7000000000000002, min_samples=10
# Silhouette Score: -0.12579193304990427
# Running DBSCAN with eps=1.7000000000000002, min_samples=12
# Silhouette Score: -0.12631196478519272
# Running DBSCAN with eps=1.7000000000000002, min_samples=14
# Silhouette Score: -0.12631196478519272
# Running DBSCAN with eps=1.7000000000000002, min_samples=16
# Silhouette Score: -0.12684356075279093
# Running DBSCAN with eps=1.7000000000000002, min_samples=18
# Silhouette Score: -0.12684356075279093
# Running DBSCAN with eps=1.7000000000000002, min_samples=20
# Silhouette Score: -0.12738916518738858
# Running DBSCAN with eps=1.7000000000000002, min_samples=22
# Silhouette Score: -0.12738916518738858
# Running DBSCAN with eps=1.7000000000000002, min_samples=24
# Silhouette Score: -0.1299324387809814
# Running DBSCAN with eps=1.7000000000000002, min_samples=26
# Silhouette Score: -0.13113237851493822
# Running DBSCAN with eps=1.7000000000000002, min_samples=28
# Silhouette Score: -0.13113237851493822
# Running DBSCAN with eps=1.7000000000000002, min_samples=30
# Silhouette Score: -0.13113237851493822
# Running DBSCAN with eps=1.8000000000000003, min_samples=2
# Silhouette Score: -0.21292821065514825
# Running DBSCAN with eps=1.8000000000000003, min_samples=4
# Silhouette Score: -0.10421000573915538
# Running DBSCAN with eps=1.8000000000000003, min_samples=6
# Silhouette Score: -0.17678494999849528
# Running DBSCAN with eps=1.8000000000000003, min_samples=8
# Silhouette Score: -0.11347282008883137
# Running DBSCAN with eps=1.8000000000000003, min_samples=10
# Silhouette Score: -0.1165420502825494
# Running DBSCAN with eps=1.8000000000000003, min_samples=12
# Silhouette Score: -0.1171889449561352
# Running DBSCAN with eps=1.8000000000000003, min_samples=14
# Silhouette Score: -0.11761469251869466
# Running DBSCAN with eps=1.8000000000000003, min_samples=16
# Silhouette Score: -0.11813508113714337
# Running DBSCAN with eps=1.8000000000000003, min_samples=18
# Silhouette Score: -0.11813508113714337
# Running DBSCAN with eps=1.8000000000000003, min_samples=20
# Silhouette Score: -0.11866088200564522
# Running DBSCAN with eps=1.8000000000000003, min_samples=22
# Silhouette Score: -0.11959261157049143
# Running DBSCAN with eps=1.8000000000000003, min_samples=24
# Silhouette Score: -0.11959261157049143
# Running DBSCAN with eps=1.8000000000000003, min_samples=26
# Silhouette Score: -0.11959261157049143
# Running DBSCAN with eps=1.8000000000000003, min_samples=28
# Silhouette Score: -0.12015103109306643
# Running DBSCAN with eps=1.8000000000000003, min_samples=30
# Silhouette Score: -0.12075659664800156
# Running DBSCAN with eps=1.9000000000000001, min_samples=2
# Silhouette Score: -0.2064122523285893
# Running DBSCAN with eps=1.9000000000000001, min_samples=4
# Silhouette Score: -0.13946218967734073
# Running DBSCAN with eps=1.9000000000000001, min_samples=6
# Silhouette Score: -0.1581232438525206
# Running DBSCAN with eps=1.9000000000000001, min_samples=8
# Silhouette Score: -0.10294897822082731
# Running DBSCAN with eps=1.9000000000000001, min_samples=10
# Silhouette Score: -0.10628763419219521
# Running DBSCAN with eps=1.9000000000000001, min_samples=12
# Silhouette Score: -0.10628763419219521
# Running DBSCAN with eps=1.9000000000000001, min_samples=14
# Silhouette Score: -0.10628763419219521
# Running DBSCAN with eps=1.9000000000000001, min_samples=16
# Silhouette Score: -0.10887143317554623
# Running DBSCAN with eps=1.9000000000000001, min_samples=18
# Silhouette Score: -0.11059005284477971
# Running DBSCAN with eps=1.9000000000000001, min_samples=20
# Silhouette Score: -0.11059005284477971
# Running DBSCAN with eps=1.9000000000000001, min_samples=22
# Silhouette Score: -0.11101769586303456
# Running DBSCAN with eps=1.9000000000000001, min_samples=24
# Silhouette Score: -0.11101769586303456
# Running DBSCAN with eps=1.9000000000000001, min_samples=26
# Silhouette Score: -0.1116968669205997
# Running DBSCAN with eps=1.9000000000000001, min_samples=28
# Silhouette Score: -0.11270114937394762
# Running DBSCAN with eps=1.9000000000000001, min_samples=30
# Silhouette Score: -0.11270114937394762
# Running DBSCAN with eps=2.0, min_samples=2
# Silhouette Score: -0.21013095848825583
# Running DBSCAN with eps=2.0, min_samples=4
# Silhouette Score: -0.08230538796258437
# Running DBSCAN with eps=2.0, min_samples=6
# Silhouette Score: -0.08644519290152687
# Running DBSCAN with eps=2.0, min_samples=8
# Silhouette Score: -0.08410957594643136
# Running DBSCAN with eps=2.0, min_samples=10
# Silhouette Score: -0.14845686073601674
# Running DBSCAN with eps=2.0, min_samples=12
# Silhouette Score: -0.09439420708079367
# Running DBSCAN with eps=2.0, min_samples=14
# Silhouette Score: -0.09713733468834801
# Running DBSCAN with eps=2.0, min_samples=16
# Silhouette Score: -0.09910007522611687
# Running DBSCAN with eps=2.0, min_samples=18
# Silhouette Score: -0.09910007522611687
# Running DBSCAN with eps=2.0, min_samples=20
# Silhouette Score: -0.09910007522611687
# Running DBSCAN with eps=2.0, min_samples=22
# Silhouette Score: -0.09910007522611687
# Running DBSCAN with eps=2.0, min_samples=24
# Silhouette Score: -0.10223750092012394
# Running DBSCAN with eps=2.0, min_samples=26
# Silhouette Score: -0.1026594529856202
# Running DBSCAN with eps=2.0, min_samples=28
# Silhouette Score: -0.10334759663019419
# Running DBSCAN with eps=2.0, min_samples=30
# Silhouette Score: -0.10334759663019419

# %%
# 최적의 파라미터로 DBSCAN 클러스터링 수행
if best_dbscan_params:
    eps, min_samples = best_dbscan_params
    print(f"Best DBSCAN params: eps={eps}, min_samples={min_samples} with Silhouette Score={best_dbscan_score}")
    dbscan = DBSCAN(eps=eps, min_samples=min_samples, metric='euclidean')
    clusters = dbscan.fit_predict(X_scaled)

    # 각 클러스터에 속한 파일들 출력 및 CSV 저장
    clustered_files = {}
    for file, cluster in zip(vector_files, clusters):
        if cluster not in clustered_files:
            clustered_files[cluster] = []
        clustered_files[cluster].append(file)

    # 클러스터 결과 출력
    n_clusters = len(set(clusters)) - (1 if -1 in clusters else 0)
    n_noise = list(clusters).count(-1)
    print(f"Number of clusters: {n_clusters}")
    print(f"Number of noise points: {n_noise}")

    # 각 클러스터의 파일 리스트 출력
    for cluster, file_list in clustered_files.items():
